# %%
import os
import sys
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
source_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(source_path)

import warnings
warnings.filterwarnings("ignore")

# %%
script_name = source_path+"/scripts/deep_feature_extraction.py"
input_preprocessed='icdar_train_df_patches_20250716_120511.csv'
selected_models = ['clip-vit-large-patch14','resnet50']
huggingface_parameter = [True, False]
already_extracted_models = []
is_train = 'val' #val, test, train
if is_train == 'val':
    zarr='test_public_writers'
elif is_train == 'test':
    zarr='test_private_writers'
else:
    zarr='train_writers'

# %% [markdown]
# reference for datasets, models, etc ..
# 'icdar_train_df_words_sentences_20250522_230307.csv'
# 'icdar_train_df_patches_20250515_164130.csv'
# icdar_train_df_patches_20250716_113702.csv (resolution 224, stride 112)
# icdar_train_df_patches_20250716_115204.csv (resolution 224, stride 112, n_cc=1) private
# icdar_train_df_patches_20250716_120511.csv (resolution 224, stride 112, n_cc=1) public
# icdar_train_df_body_20250716_123551.csv body publicù
#
# selected_models = ['trocr-small-stage1', 'trocr-small-handwritten', 'resnet50',
#                    'vit-base-patch16-224-in21k', 'trocr-base-handwritten', 'clip-vit-large-patch14',
#                    'trocr-large-handwritten', 'dresnet50', 'crnn_vgg16_bn',
#                    'vitstr_base', 'trocr-large-stage1', 'trocr-base-stage1',
#                    'alexnet', 'vgg16', 'googlenet']
# huggingface_parameter = [True, True, False,
#                          True, True, True,
#                          True, False, False,
#                          False, True, True,
#                          False,False, False]
#
# already_extracted_models = ['resnet50', 'vit-base-patch16-224-in21k', 'trocr-base-handwritten','clip-vit-large-patch14','dresnet50']

# %% [markdown]
# # launch deep_feature_extraction script

# %%
for i,model in enumerate(selected_models):
    if model in already_extracted_models:
        print(f"Skipping {model} as it has already been extracted.")
        continue
    save_dir = source_path+f'\\outputs\\online_deep_feature_extraction\\{selected_models[i]}\\representation_extraction\\extracted_representation\\{is_train}'
    file_IO.access_or_create_dir(save_dir)
    args = script_launching.DotDict(
        N_max=282,
        patches=True,
        input_filename=input_preprocessed,
        huggingface=huggingface_parameter[i],
        pooling=False,  # if true in transformer models use pooling, if false only the cls token
        custom_transform=False,
        transform_mode='resize',
        save_h5=False,
        selected_model=model,  # googlenet, alexnet
        truncation='remove head',
        running='new-laptop',
        saved='old-laptop',
        model_mode='truncated',  # 'truncation
        batching=True,
        batch_size=64,
        select_cls=False,
        num_workers=4,
        pin_memory=True,
        show_image=False,
        save_to_log=False,  # Save the extracted features to a log file
        data_augmentation=True,
        num_views=1,  # Number of views for data augmentation
        save_dir=save_dir,
        n_patches=20,
        zarr_path = f"C:\\Users\\andre\PhD\Datasets\ICDAR 2013 - Gender Identification Competition Dataset\\{zarr}.zarr"
        #script_mode='standalone'
    )
    script_launching.run_experiment_threaded(args,script_name)  # Test a single run first
# Out:
# Starting experiment: file=icdar_train_df_patches_20250716_120511.csv, model=clip-vit-large-patch14
# [STDOUT] Device is:  cuda
# [STDOUT] Output shape:  torch.Size([1, 768])
# [STDOUT] Elapsed time 2.02;Processed batch 1 out of 89; Speed: 63.44 images/sec;
# [STDOUT]                         Projected time: 88.78 seconds
# [STDOUT] Elapsed time 4.04;Processed batch 2 out of 89; Speed: 47.54 images/sec;
# [STDOUT]                         Projected time: 117.12 seconds
# [STDOUT] Elapsed time 6.04;Processed batch 3 out of 89; Speed: 42.36 images/sec;
# [STDOUT]                         Projected time: 129.95 seconds
# [STDOUT] Elapsed time 8.08;Processed batch 4 out of 89; Speed: 39.62 images/sec;
# [STDOUT]                         Projected time: 137.29 seconds
# [STDOUT] Elapsed time 10.08;Processed batch 5 out of 89; Speed: 38.08 images/sec;
# [STDOUT]                         Projected time: 141.19 seconds
# [STDOUT] Elapsed time 12.12;Processed batch 6 out of 89; Speed: 36.97 images/sec;
# [STDOUT]                         Projected time: 143.69 seconds
# [STDOUT] Elapsed time 14.13;Processed batch 7 out of 89; Speed: 36.23 images/sec;
# [STDOUT]                         Projected time: 144.86 seconds
# [STDOUT] Elapsed time 16.15;Processed batch 8 out of 89; Speed: 35.66 images/sec;
# [STDOUT]                         Projected time: 145.39 seconds
# [STDOUT] Elapsed time 18.19;Processed batch 9 out of 89; Speed: 35.19 images/sec;
# [STDOUT]                         Projected time: 145.51 seconds
# [STDOUT] Elapsed time 20.25;Processed batch 10 out of 89; Speed: 34.77 images/sec;
# [STDOUT]                         Projected time: 145.42 seconds
# [STDOUT] Elapsed time 22.27;Processed batch 11 out of 89; Speed: 34.48 images/sec;
# [STDOUT]                         Projected time: 144.78 seconds
# [STDOUT] Elapsed time 24.32;Processed batch 12 out of 89; Speed: 34.21 images/sec;
# [STDOUT]                         Projected time: 144.04 seconds
# [STDOUT] Elapsed time 26.35;Processed batch 13 out of 89; Speed: 34.01 images/sec;
# [STDOUT]                         Projected time: 143.03 seconds
# [STDOUT] Elapsed time 28.40;Processed batch 14 out of 89; Speed: 33.80 images/sec;
# [STDOUT]                         Projected time: 142.00 seconds
# [STDOUT] Elapsed time 30.44;Processed batch 15 out of 89; Speed: 33.63 images/sec;
# [STDOUT]                         Projected time: 140.81 seconds
# [STDOUT] Elapsed time 32.47;Processed batch 16 out of 89; Speed: 33.50 images/sec;
# [STDOUT]                         Projected time: 139.45 seconds
# [STDOUT] Elapsed time 34.53;Processed batch 17 out of 89; Speed: 33.36 images/sec;
# [STDOUT]                         Projected time: 138.13 seconds
# [STDOUT] Elapsed time 36.58;Processed batch 18 out of 89; Speed: 33.24 images/sec;
# [STDOUT]                         Projected time: 136.71 seconds
# [STDOUT] Elapsed time 38.64;Processed batch 19 out of 89; Speed: 33.13 images/sec;
# [STDOUT]                         Projected time: 135.24 seconds
# [STDOUT] Elapsed time 40.70;Processed batch 20 out of 89; Speed: 33.02 images/sec;
# [STDOUT]                         Projected time: 133.74 seconds
# [STDOUT] Elapsed time 42.76;Processed batch 21 out of 89; Speed: 32.93 images/sec;
# [STDOUT]                         Projected time: 132.15 seconds
# [STDOUT] Elapsed time 44.82;Processed batch 22 out of 89; Speed: 32.84 images/sec;
# [STDOUT]                         Projected time: 130.57 seconds
# [STDOUT] Elapsed time 46.88;Processed batch 23 out of 89; Speed: 32.76 images/sec;
# [STDOUT]                         Projected time: 128.93 seconds
# [STDOUT] Elapsed time 48.95;Processed batch 24 out of 89; Speed: 32.69 images/sec;
# [STDOUT]                         Projected time: 127.27 seconds
# [STDOUT] Elapsed time 51.02;Processed batch 25 out of 89; Speed: 32.62 images/sec;
# [STDOUT]                         Projected time: 125.58 seconds
# [STDOUT] Elapsed time 53.08;Processed batch 26 out of 89; Speed: 32.55 images/sec;
# [STDOUT]                         Projected time: 123.86 seconds
# [STDOUT] Elapsed time 55.14;Processed batch 27 out of 89; Speed: 32.50 images/sec;
# [STDOUT]                         Projected time: 122.10 seconds
# [STDOUT] Elapsed time 57.22;Processed batch 28 out of 89; Speed: 32.44 images/sec;
# [STDOUT]                         Projected time: 120.36 seconds
# [STDOUT] Elapsed time 59.28;Processed batch 29 out of 89; Speed: 32.39 images/sec;
# [STDOUT]                         Projected time: 118.56 seconds
# [STDOUT] Elapsed time 61.34;Processed batch 30 out of 89; Speed: 32.34 images/sec;
# [STDOUT]                         Projected time: 116.75 seconds
# [STDOUT] Elapsed time 63.42;Processed batch 31 out of 89; Speed: 32.29 images/sec;
# [STDOUT]                         Projected time: 114.94 seconds
# [STDOUT] Elapsed time 65.48;Processed batch 32 out of 89; Speed: 32.25 images/sec;
# [STDOUT]                         Projected time: 113.11 seconds
# [STDOUT] Elapsed time 67.55;Processed batch 33 out of 89; Speed: 32.21 images/sec;
# [STDOUT]                         Projected time: 111.26 seconds
# [STDOUT] Elapsed time 69.62;Processed batch 34 out of 89; Speed: 32.18 images/sec;
# [STDOUT]                         Projected time: 109.40 seconds
# [STDOUT] Elapsed time 71.68;Processed batch 35 out of 89; Speed: 32.14 images/sec;
# [STDOUT]                         Projected time: 107.51 seconds
# [STDOUT] Elapsed time 73.74;Processed batch 36 out of 89; Speed: 32.11 images/sec;
# [STDOUT]                         Projected time: 105.63 seconds
# [STDOUT] Elapsed time 75.81;Processed batch 37 out of 89; Speed: 32.08 images/sec;
# [STDOUT]                         Projected time: 103.74 seconds
# [STDOUT] Elapsed time 77.86;Processed batch 38 out of 89; Speed: 32.06 images/sec;
# [STDOUT]                         Projected time: 101.82 seconds
# [STDOUT] Elapsed time 79.92;Processed batch 39 out of 89; Speed: 32.03 images/sec;
# [STDOUT]                         Projected time: 99.90 seconds
# [STDOUT] Elapsed time 81.98;Processed batch 40 out of 89; Speed: 32.01 images/sec;
# [STDOUT]                         Projected time: 97.98 seconds
# [STDOUT] Elapsed time 84.04;Processed batch 41 out of 89; Speed: 31.99 images/sec;
# [STDOUT]                         Projected time: 96.04 seconds
# [STDOUT] Elapsed time 86.10;Processed batch 42 out of 89; Speed: 31.96 images/sec;
# [STDOUT]                         Projected time: 94.10 seconds
# [STDOUT] Elapsed time 88.15;Processed batch 43 out of 89; Speed: 31.95 images/sec;
# [STDOUT]                         Projected time: 92.16 seconds
# [STDOUT] Elapsed time 90.20;Processed batch 44 out of 89; Speed: 31.93 images/sec;
# [STDOUT]                         Projected time: 90.20 seconds
# [STDOUT] Elapsed time 92.26;Processed batch 45 out of 89; Speed: 31.91 images/sec;
# [STDOUT]                         Projected time: 88.25 seconds
# [STDOUT] Elapsed time 94.32;Processed batch 46 out of 89; Speed: 31.89 images/sec;
# [STDOUT]                         Projected time: 86.29 seconds
# [STDOUT] Elapsed time 96.37;Processed batch 47 out of 89; Speed: 31.88 images/sec;
# [STDOUT]                         Projected time: 84.32 seconds
# [STDOUT] Elapsed time 98.43;Processed batch 48 out of 89; Speed: 31.86 images/sec;
# [STDOUT]                         Projected time: 82.36 seconds
# [STDOUT] Elapsed time 100.49;Processed batch 49 out of 89; Speed: 31.84 images/sec;
# [STDOUT]                         Projected time: 80.39 seconds
# [STDOUT] Elapsed time 102.54;Processed batch 50 out of 89; Speed: 31.83 images/sec;
# [STDOUT]                         Projected time: 78.41 seconds
# [STDOUT] Elapsed time 104.59;Processed batch 51 out of 89; Speed: 31.82 images/sec;
# [STDOUT]                         Projected time: 76.43 seconds
# [STDOUT] Elapsed time 106.64;Processed batch 52 out of 89; Speed: 31.81 images/sec;
# [STDOUT]                         Projected time: 74.45 seconds
# [STDOUT] Elapsed time 108.70;Processed batch 53 out of 89; Speed: 31.79 images/sec;
# [STDOUT]                         Projected time: 72.47 seconds
# [STDOUT] Elapsed time 110.76;Processed batch 54 out of 89; Speed: 31.78 images/sec;
# [STDOUT]                         Projected time: 70.48 seconds
# [STDOUT] Elapsed time 112.81;Processed batch 55 out of 89; Speed: 31.77 images/sec;
# [STDOUT]                         Projected time: 68.49 seconds
# [STDOUT] Elapsed time 114.87;Processed batch 56 out of 89; Speed: 31.76 images/sec;
# [STDOUT]                         Projected time: 66.51 seconds
# [STDOUT] Elapsed time 116.92;Processed batch 57 out of 89; Speed: 31.75 images/sec;
# [STDOUT]                         Projected time: 64.51 seconds
# [STDOUT] Elapsed time 118.97;Processed batch 58 out of 89; Speed: 31.74 images/sec;
# [STDOUT]                         Projected time: 62.51 seconds
# [STDOUT] Elapsed time 121.04;Processed batch 59 out of 89; Speed: 31.73 images/sec;
# [STDOUT]                         Projected time: 60.52 seconds
# [STDOUT] Elapsed time 123.09;Processed batch 60 out of 89; Speed: 31.72 images/sec;
# [STDOUT]                         Projected time: 58.52 seconds
# [STDOUT] Elapsed time 125.15;Processed batch 61 out of 89; Speed: 31.71 images/sec;
# [STDOUT]                         Projected time: 56.52 seconds
# [STDOUT] Elapsed time 127.21;Processed batch 62 out of 89; Speed: 31.70 images/sec;
# [STDOUT]                         Projected time: 54.52 seconds
# [STDOUT] Elapsed time 129.27;Processed batch 63 out of 89; Speed: 31.69 images/sec;
# [STDOUT]                         Projected time: 52.51 seconds
# [STDOUT] Elapsed time 131.34;Processed batch 64 out of 89; Speed: 31.67 images/sec;
# [STDOUT]                         Projected time: 50.51 seconds
# [STDOUT] Elapsed time 133.39;Processed batch 65 out of 89; Speed: 31.67 images/sec;
# [STDOUT]                         Projected time: 48.51 seconds
# [STDOUT] Elapsed time 135.44;Processed batch 66 out of 89; Speed: 31.66 images/sec;
# [STDOUT]                         Projected time: 46.49 seconds
# [STDOUT] Elapsed time 137.49;Processed batch 67 out of 89; Speed: 31.65 images/sec;
# [STDOUT]                         Projected time: 44.48 seconds
# [STDOUT] Elapsed time 139.55;Processed batch 68 out of 89; Speed: 31.65 images/sec;
# [STDOUT]                         Projected time: 42.47 seconds
# [STDOUT] Elapsed time 141.60;Processed batch 69 out of 89; Speed: 31.64 images/sec;
# [STDOUT]                         Projected time: 40.46 seconds
# [STDOUT] Elapsed time 143.67;Processed batch 70 out of 89; Speed: 31.63 images/sec;
# [STDOUT]                         Projected time: 38.45 seconds
# [STDOUT] Elapsed time 145.75;Processed batch 71 out of 89; Speed: 31.62 images/sec;
# [STDOUT]                         Projected time: 36.44 seconds
# [STDOUT] Elapsed time 147.81;Processed batch 72 out of 89; Speed: 31.61 images/sec;
# [STDOUT]                         Projected time: 34.42 seconds
# [STDOUT] Elapsed time 149.86;Processed batch 73 out of 89; Speed: 31.60 images/sec;
# [STDOUT]                         Projected time: 32.40 seconds
# [STDOUT] Elapsed time 151.94;Processed batch 74 out of 89; Speed: 31.59 images/sec;
# [STDOUT]                         Projected time: 30.39 seconds
# [STDOUT] Elapsed time 154.00;Processed batch 75 out of 89; Speed: 31.58 images/sec;
# [STDOUT]                         Projected time: 28.37 seconds
# [STDOUT] Elapsed time 156.05;Processed batch 76 out of 89; Speed: 31.58 images/sec;
# [STDOUT]                         Projected time: 26.35 seconds
# [STDOUT] Elapsed time 158.12;Processed batch 77 out of 89; Speed: 31.57 images/sec;
# [STDOUT]                         Projected time: 24.33 seconds
# [STDOUT] Elapsed time 160.19;Processed batch 78 out of 89; Speed: 31.56 images/sec;
# [STDOUT]                         Projected time: 22.30 seconds
# [STDOUT] Elapsed time 162.24;Processed batch 79 out of 89; Speed: 31.56 images/sec;
# [STDOUT]                         Projected time: 20.28 seconds
# [STDOUT] Elapsed time 164.30;Processed batch 80 out of 89; Speed: 31.55 images/sec;
# [STDOUT]                         Projected time: 18.26 seconds
# [STDOUT] Elapsed time 166.36;Processed batch 81 out of 89; Speed: 31.55 images/sec;
# [STDOUT]                         Projected time: 16.23 seconds
# [STDOUT] Elapsed time 168.42;Processed batch 82 out of 89; Speed: 31.54 images/sec;
# [STDOUT]                         Projected time: 14.20 seconds
# [STDOUT] Elapsed time 170.47;Processed batch 83 out of 89; Speed: 31.54 images/sec;
# [STDOUT]                         Projected time: 12.18 seconds
# [STDOUT] Elapsed time 172.52;Processed batch 84 out of 89; Speed: 31.53 images/sec;
# [STDOUT]                         Projected time: 10.15 seconds
# [STDOUT] Elapsed time 174.58;Processed batch 85 out of 89; Speed: 31.53 images/sec;
# [STDOUT]                         Projected time: 8.12 seconds
# [STDOUT] Elapsed time 176.63;Processed batch 86 out of 89; Speed: 31.52 images/sec;
# [STDOUT]                         Projected time: 6.09 seconds
# [STDOUT] Elapsed time 178.69;Processed batch 87 out of 89; Speed: 31.52 images/sec;
# [STDOUT]                         Projected time: 4.06 seconds
# [STDOUT] Elapsed time 180.23;Processed batch 88 out of 89; Speed: 31.51 images/sec;
# [STDOUT]                         Projected time: 2.03 seconds
# Experiment finished with return code: 0
# Starting experiment: file=icdar_train_df_patches_20250716_120511.csv, model=resnet50
# [STDOUT] Device is:  cuda
# [STDOUT] Output shape:  torch.Size([1, 2048])
# [STDOUT] Elapsed time 0.14;Processed batch 1 out of 89; Speed: 907.05 images/sec;
# [STDOUT]                         Projected time: 6.21 seconds
# [STDOUT] Elapsed time 0.26;Processed batch 2 out of 89; Speed: 731.03 images/sec;
# [STDOUT]                         Projected time: 7.62 seconds
# [STDOUT] Elapsed time 0.41;Processed batch 3 out of 89; Speed: 629.30 images/sec;
# [STDOUT]                         Projected time: 8.75 seconds
# [STDOUT] Elapsed time 1.81;Processed batch 4 out of 89; Speed: 176.53 images/sec;
# [STDOUT]                         Projected time: 30.82 seconds
# [STDOUT] Elapsed time 1.96;Processed batch 5 out of 89; Speed: 196.28 images/sec;
# [STDOUT]                         Projected time: 27.39 seconds
# [STDOUT] Elapsed time 2.09;Processed batch 6 out of 89; Speed: 214.58 images/sec;
# [STDOUT]                         Projected time: 24.75 seconds
# [STDOUT] Elapsed time 2.22;Processed batch 7 out of 89; Speed: 231.05 images/sec;
# [STDOUT]                         Projected time: 22.71 seconds
# [STDOUT] Elapsed time 3.81;Processed batch 8 out of 89; Speed: 151.34 images/sec;
# [STDOUT]                         Projected time: 34.25 seconds
# [STDOUT] Elapsed time 3.93;Processed batch 9 out of 89; Speed: 162.85 images/sec;
# [STDOUT]                         Projected time: 31.44 seconds
# [STDOUT] Elapsed time 4.07;Processed batch 10 out of 89; Speed: 173.17 images/sec;
# [STDOUT]                         Projected time: 29.20 seconds
# [STDOUT] Elapsed time 4.21;Processed batch 11 out of 89; Speed: 182.57 images/sec;
# [STDOUT]                         Projected time: 27.34 seconds
# [STDOUT] Elapsed time 5.82;Processed batch 12 out of 89; Speed: 142.94 images/sec;
# [STDOUT]                         Projected time: 34.48 seconds
# [STDOUT] Elapsed time 5.95;Processed batch 13 out of 89; Speed: 150.61 images/sec;
# [STDOUT]                         Projected time: 32.30 seconds
# [STDOUT] Elapsed time 6.07;Processed batch 14 out of 89; Speed: 158.09 images/sec;
# [STDOUT]                         Projected time: 30.36 seconds
# [STDOUT] Elapsed time 6.21;Processed batch 15 out of 89; Speed: 164.84 images/sec;
# [STDOUT]                         Projected time: 28.73 seconds
# [STDOUT] Elapsed time 7.95;Processed batch 16 out of 89; Speed: 136.88 images/sec;
# [STDOUT]                         Projected time: 34.13 seconds
# [STDOUT] Elapsed time 8.08;Processed batch 17 out of 89; Speed: 142.57 images/sec;
# [STDOUT]                         Projected time: 32.32 seconds
# [STDOUT] Elapsed time 8.22;Processed batch 18 out of 89; Speed: 147.90 images/sec;
# [STDOUT]                         Projected time: 30.72 seconds
# [STDOUT] Elapsed time 8.36;Processed batch 19 out of 89; Speed: 153.13 images/sec;
# [STDOUT]                         Projected time: 29.26 seconds
# [STDOUT] Elapsed time 10.22;Processed batch 20 out of 89; Speed: 131.56 images/sec;
# [STDOUT]                         Projected time: 33.57 seconds
# [STDOUT] Elapsed time 10.35;Processed batch 21 out of 89; Speed: 136.07 images/sec;
# [STDOUT]                         Projected time: 31.98 seconds
# [STDOUT] Elapsed time 10.49;Processed batch 22 out of 89; Speed: 140.34 images/sec;
# [STDOUT]                         Projected time: 30.55 seconds
# [STDOUT] Elapsed time 10.63;Processed batch 23 out of 89; Speed: 144.55 images/sec;
# [STDOUT]                         Projected time: 29.22 seconds
# [STDOUT] Elapsed time 12.20;Processed batch 24 out of 89; Speed: 131.18 images/sec;
# [STDOUT]                         Projected time: 31.71 seconds
# [STDOUT] Elapsed time 12.33;Processed batch 25 out of 89; Speed: 134.96 images/sec;
# [STDOUT]                         Projected time: 30.35 seconds
# [STDOUT] Elapsed time 12.45;Processed batch 26 out of 89; Speed: 138.80 images/sec;
# [STDOUT]                         Projected time: 29.05 seconds
# [STDOUT] Elapsed time 12.58;Processed batch 27 out of 89; Speed: 142.42 images/sec;
# [STDOUT]                         Projected time: 27.86 seconds
# [STDOUT] Elapsed time 14.22;Processed batch 28 out of 89; Speed: 130.51 images/sec;
# [STDOUT]                         Projected time: 29.91 seconds
# [STDOUT] Elapsed time 14.36;Processed batch 29 out of 89; Speed: 133.69 images/sec;
# [STDOUT]                         Projected time: 28.72 seconds
# [STDOUT] Elapsed time 14.49;Processed batch 30 out of 89; Speed: 136.92 images/sec;
# [STDOUT]                         Projected time: 27.58 seconds
# [STDOUT] Elapsed time 14.61;Processed batch 31 out of 89; Speed: 140.13 images/sec;
# [STDOUT]                         Projected time: 26.49 seconds
# [STDOUT] Elapsed time 16.17;Processed batch 32 out of 89; Speed: 130.59 images/sec;
# [STDOUT]                         Projected time: 27.93 seconds
# [STDOUT] Elapsed time 16.32;Processed batch 33 out of 89; Speed: 133.35 images/sec;
# [STDOUT]                         Projected time: 26.88 seconds
# [STDOUT] Elapsed time 16.45;Processed batch 34 out of 89; Speed: 136.18 images/sec;
# [STDOUT]                         Projected time: 25.85 seconds
# [STDOUT] Elapsed time 16.59;Processed batch 35 out of 89; Speed: 138.92 images/sec;
# [STDOUT]                         Projected time: 24.88 seconds
# [STDOUT] Elapsed time 18.32;Processed batch 36 out of 89; Speed: 129.28 images/sec;
# [STDOUT]                         Projected time: 26.24 seconds
# [STDOUT] Elapsed time 18.45;Processed batch 37 out of 89; Speed: 131.81 images/sec;
# [STDOUT]                         Projected time: 25.25 seconds
# [STDOUT] Elapsed time 18.58;Processed batch 38 out of 89; Speed: 134.31 images/sec;
# [STDOUT]                         Projected time: 24.30 seconds
# [STDOUT] Elapsed time 18.72;Processed batch 39 out of 89; Speed: 136.78 images/sec;
# [STDOUT]                         Projected time: 23.40 seconds
# [STDOUT] Elapsed time 20.78;Processed batch 40 out of 89; Speed: 126.26 images/sec;
# [STDOUT]                         Projected time: 24.84 seconds
# [STDOUT] Elapsed time 20.92;Processed batch 41 out of 89; Speed: 128.46 images/sec;
# [STDOUT]                         Projected time: 23.91 seconds
# [STDOUT] Elapsed time 21.06;Processed batch 42 out of 89; Speed: 130.68 images/sec;
# [STDOUT]                         Projected time: 23.02 seconds
# [STDOUT] Elapsed time 21.19;Processed batch 43 out of 89; Speed: 132.89 images/sec;
# [STDOUT]                         Projected time: 22.15 seconds
# [STDOUT] Elapsed time 22.95;Processed batch 44 out of 89; Speed: 125.49 images/sec;
# [STDOUT]                         Projected time: 22.95 seconds
# [STDOUT] Elapsed time 23.08;Processed batch 45 out of 89; Speed: 127.54 images/sec;
# [STDOUT]                         Projected time: 22.08 seconds
# [STDOUT] Elapsed time 23.22;Processed batch 46 out of 89; Speed: 129.56 images/sec;
# [STDOUT]                         Projected time: 21.24 seconds
# [STDOUT] Elapsed time 23.35;Processed batch 47 out of 89; Speed: 131.55 images/sec;
# [STDOUT]                         Projected time: 20.43 seconds
# [STDOUT] Elapsed time 25.13;Processed batch 48 out of 89; Speed: 124.78 images/sec;
# [STDOUT]                         Projected time: 21.03 seconds
# [STDOUT] Elapsed time 25.26;Processed batch 49 out of 89; Speed: 126.70 images/sec;
# [STDOUT]                         Projected time: 20.21 seconds
# [STDOUT] Elapsed time 25.39;Processed batch 50 out of 89; Speed: 128.55 images/sec;
# [STDOUT]                         Projected time: 19.42 seconds
# [STDOUT] Elapsed time 25.53;Processed batch 51 out of 89; Speed: 130.33 images/sec;
# [STDOUT]                         Projected time: 18.66 seconds
# [STDOUT] Elapsed time 27.08;Processed batch 52 out of 89; Speed: 125.25 images/sec;
# [STDOUT]                         Projected time: 18.91 seconds
# [STDOUT] Elapsed time 27.23;Processed batch 53 out of 89; Speed: 126.92 images/sec;
# [STDOUT]                         Projected time: 18.15 seconds
# [STDOUT] Elapsed time 27.36;Processed batch 54 out of 89; Speed: 128.64 images/sec;
# [STDOUT]                         Projected time: 17.41 seconds
# [STDOUT] Elapsed time 27.50;Processed batch 55 out of 89; Speed: 130.34 images/sec;
# [STDOUT]                         Projected time: 16.70 seconds
# [STDOUT] Elapsed time 29.03;Processed batch 56 out of 89; Speed: 125.66 images/sec;
# [STDOUT]                         Projected time: 16.81 seconds
# [STDOUT] Elapsed time 29.18;Processed batch 57 out of 89; Speed: 127.21 images/sec;
# [STDOUT]                         Projected time: 16.10 seconds
# [STDOUT] Elapsed time 29.33;Processed batch 58 out of 89; Speed: 128.76 images/sec;
# [STDOUT]                         Projected time: 15.41 seconds
# [STDOUT] Elapsed time 29.46;Processed batch 59 out of 89; Speed: 130.37 images/sec;
# [STDOUT]                         Projected time: 14.73 seconds
# [STDOUT] Elapsed time 31.40;Processed batch 60 out of 89; Speed: 124.35 images/sec;
# [STDOUT]                         Projected time: 14.93 seconds
# [STDOUT] Elapsed time 31.53;Processed batch 61 out of 89; Speed: 125.85 images/sec;
# [STDOUT]                         Projected time: 14.24 seconds
# [STDOUT] Elapsed time 31.66;Processed batch 62 out of 89; Speed: 127.37 images/sec;
# [STDOUT]                         Projected time: 13.57 seconds
# [STDOUT] Elapsed time 31.80;Processed batch 63 out of 89; Speed: 128.82 images/sec;
# [STDOUT]                         Projected time: 12.92 seconds
# [STDOUT] Elapsed time 33.39;Processed batch 64 out of 89; Speed: 124.60 images/sec;
# [STDOUT]                         Projected time: 12.84 seconds
# [STDOUT] Elapsed time 33.52;Processed batch 65 out of 89; Speed: 126.02 images/sec;
# [STDOUT]                         Projected time: 12.19 seconds
# [STDOUT] Elapsed time 33.65;Processed batch 66 out of 89; Speed: 127.42 images/sec;
# [STDOUT]                         Projected time: 11.55 seconds
# [STDOUT] Elapsed time 33.78;Processed batch 67 out of 89; Speed: 128.82 images/sec;
# [STDOUT]                         Projected time: 10.93 seconds
# [STDOUT] Elapsed time 35.44;Processed batch 68 out of 89; Speed: 124.59 images/sec;
# [STDOUT]                         Projected time: 10.79 seconds
# [STDOUT] Elapsed time 35.58;Processed batch 69 out of 89; Speed: 125.90 images/sec;
# [STDOUT]                         Projected time: 10.17 seconds
# [STDOUT] Elapsed time 35.72;Processed batch 70 out of 89; Speed: 127.23 images/sec;
# [STDOUT]                         Projected time: 9.56 seconds
# [STDOUT] Elapsed time 35.85;Processed batch 71 out of 89; Speed: 128.55 images/sec;
# [STDOUT]                         Projected time: 8.96 seconds
# [STDOUT] Elapsed time 37.70;Processed batch 72 out of 89; Speed: 123.93 images/sec;
# [STDOUT]                         Projected time: 8.78 seconds
# [STDOUT] Elapsed time 37.84;Processed batch 73 out of 89; Speed: 125.16 images/sec;
# [STDOUT]                         Projected time: 8.18 seconds
# [STDOUT] Elapsed time 37.97;Processed batch 74 out of 89; Speed: 126.40 images/sec;
# [STDOUT]                         Projected time: 7.59 seconds
# [STDOUT] Elapsed time 38.11;Processed batch 75 out of 89; Speed: 127.64 images/sec;
# [STDOUT]                         Projected time: 7.02 seconds
# [STDOUT] Elapsed time 39.76;Processed batch 76 out of 89; Speed: 123.95 images/sec;
# [STDOUT]                         Projected time: 6.71 seconds
# [STDOUT] Elapsed time 39.89;Processed batch 77 out of 89; Speed: 125.15 images/sec;
# [STDOUT]                         Projected time: 6.14 seconds
# [STDOUT] Elapsed time 40.03;Processed batch 78 out of 89; Speed: 126.30 images/sec;
# [STDOUT]                         Projected time: 5.57 seconds
# [STDOUT] Elapsed time 40.15;Processed batch 79 out of 89; Speed: 127.52 images/sec;
# [STDOUT]                         Projected time: 5.02 seconds
# [STDOUT] Elapsed time 41.83;Processed batch 80 out of 89; Speed: 123.93 images/sec;
# [STDOUT]                         Projected time: 4.65 seconds
# [STDOUT] Elapsed time 41.98;Processed batch 81 out of 89; Speed: 125.02 images/sec;
# [STDOUT]                         Projected time: 4.10 seconds
# [STDOUT] Elapsed time 42.11;Processed batch 82 out of 89; Speed: 126.16 images/sec;
# [STDOUT]                         Projected time: 3.55 seconds
# [STDOUT] Elapsed time 42.24;Processed batch 83 out of 89; Speed: 127.27 images/sec;
# [STDOUT]                         Projected time: 3.02 seconds
# [STDOUT] Elapsed time 43.65;Processed batch 84 out of 89; Speed: 124.63 images/sec;
# [STDOUT]                         Projected time: 2.57 seconds
# [STDOUT] Elapsed time 43.78;Processed batch 85 out of 89; Speed: 125.73 images/sec;
# [STDOUT]                         Projected time: 2.04 seconds
# [STDOUT] Elapsed time 43.93;Processed batch 86 out of 89; Speed: 126.76 images/sec;
# [STDOUT]                         Projected time: 1.51 seconds
# [STDOUT] Elapsed time 44.06;Processed batch 87 out of 89; Speed: 127.84 images/sec;
# [STDOUT]                         Projected time: 1.00 seconds
# [STDOUT] Elapsed time 44.97;Processed batch 88 out of 89; Speed: 126.30 images/sec;
# [STDOUT]                         Projected time: 0.51 seconds
# Experiment finished with return code: 0

# %% [markdown]
# # reload

# %%
def reload_modules():
    import importlib
    import utils.data_loading as data_loading
    import utils.visualization as visualization
    import utils.dataframes as dataframes
    import utils.utils_transforms as u_transforms
    import utils.training_utils as training_utils
    import utils.model_utils as model_utils
    import utils.file_IO as file_IO
    import utils.vit_rollout_mod as vit_rollout_mod
    import utils.script_launching as script_launching
    
    importlib.reload(file_IO)
    importlib.reload(data_loading)
    importlib.reload(visualization)
    importlib.reload(dataframes)
    importlib.reload(u_transforms)
    importlib.reload(model_utils)
    importlib.reload(training_utils)
    importlib.reload(vit_rollout_mod)
    importlib.reload(script_launching)

    return data_loading, visualization, dataframes, u_transforms, training_utils, model_utils, file_IO, vit_rollout_mod, script_launching
data_loading, visualization, dataframes, u_transforms, training_utils, model_utils, file_IO, vit_rollout_mod, script_launching = reload_modules()
