# %%
import os
import sys
import pickle
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
source_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(source_path)

import warnings
warnings.filterwarnings("ignore")

# %%
script_name = source_path+"/scripts/deep_feature_extraction.py"
input_preprocessed='icdar_train_df_body_20250523_181312.csv'
extra_view=True
selected_models = ['clip-vit-large-patch14','resnet50']
huggingface_parameter = [True, False]
already_extracted_models = ['resnet50']
data_augmentation = False  # Set to True for data augmentation
is_train = 'train' #val, test, train
if is_train == 'val':
    zarr='test_public_writers'
elif is_train == 'test':
    zarr='test_private_writers'
else:
    zarr='train_writers'

n_patches=-1

# %% [markdown]
# reference for datasets, models, etc ..
# 'icdar_train_df_words_sentences_20250522_230307.csv'
# 'icdar_train_df_patches_20250515_164130.csv'
# 'icdar_train_df_body_20250523_181312.csv'
# icdar_train_df_patches_20250716_113702.csv (resolution 224, stride 112)
# icdar_train_df_patches_20250716_115204.csv (resolution 224, stride 112, n_cc=1) private
# icdar_train_df_patches_20250716_120511.csv (resolution 224, stride 112, n_cc=1) public
# icdar_train_df_body_20250716_123551.csv body public
#
# selected_models = ['trocr-small-stage1', 'trocr-small-handwritten', 'resnet50',
#                    'vit-base-patch16-224-in21k', 'trocr-base-handwritten', 'clip-vit-large-patch14',
#                    'trocr-large-handwritten', 'dresnet50', 'crnn_vgg16_bn',
#                    'vitstr_base', 'trocr-large-stage1', 'trocr-base-stage1',
#                    'alexnet', 'vgg16', 'googlenet']
# huggingface_parameter = [True, True, False,
#                          True, True, True,
#                          True, False, False,
#                          False, True, True,
#                          False,False, False]
#
# already_extracted_models = ['resnet50', 'vit-base-patch16-224-in21k', 'trocr-base-handwritten','clip-vit-large-patch14','dresnet50']

# %% [markdown]
# # launch deep_feature_extraction script

# %%
for i,model in enumerate(selected_models):
    if model in already_extracted_models:
        print(f"Skipping {model} as it has already been extracted.")
        continue
    if data_augmentation:
        suffix = '_augmented'
    else:
        suffix=''
    if extra_view:
        save_dir = source_path+f'\\outputs\\online_deep_feature_extraction\\{selected_models[i]}\\representation_extraction\\extracted_representation\\extra_view\\{is_train}{suffix}'
    else:
        save_dir = source_path+f'\\outputs\\online_deep_feature_extraction\\{selected_models[i]}\\representation_extraction\\extracted_representation\\{is_train}{suffix}'
    file_IO.access_or_create_dir(save_dir)
    args = script_launching.DotDict(
        N_max=282,
        patches=True,
        input_filename=input_preprocessed,
        huggingface=huggingface_parameter[i],
        pooling=False,  # if true in transformer models use pooling, if false only the cls token
        custom_transform=False,
        transform_mode='resize',
        save_h5=False,
        selected_model=model,  # googlenet, alexnet
        truncation='remove head',
        running='new-laptop',
        saved='old-laptop',
        model_mode='truncated',  # 'truncation
        batching=True,
        batch_size=64,
        select_cls=False,
        num_workers=4,
        pin_memory=True,
        show_image=True,
        save_to_log=False,  # Save the extracted features to a log file
        data_augmentation=data_augmentation,
        num_views=1,  # Number of views for data augmentation
        save_dir=save_dir,
        n_patches=n_patches,
        zarr_path = f"C:\\Users\\andre\PhD\Datasets\ICDAR 2013 - Gender Identification Competition Dataset\\{zarr}.zarr"
        #script_mode='standalone'
    )
    file_IO.save_args(args,save_dir)  # Save the arguments to a file
    script_launching.run_experiment_threaded(args,script_name)  # Test a single run first
# Out:
# Starting experiment:
# [STDOUT] Device is:  cuda
# [STDOUT] Output shape:  torch.Size([1, 768])
# [STDOUT] Saving debug images...
# [STDOUT] Debug images saved.
# [STDOUT] Elapsed time 4.83;Processed batch 1 out of 18; Speed: 26.50 images/sec;
# [STDOUT]                         Projected time: 41.06 seconds
# [STDOUT] Elapsed time 9.69;Processed batch 2 out of 18; Speed: 19.82 images/sec;
# [STDOUT]                         Projected time: 51.66 seconds
# [STDOUT] Elapsed time 14.56;Processed batch 3 out of 18; Speed: 17.58 images/sec;
# [STDOUT]                         Projected time: 54.61 seconds
# [STDOUT] Elapsed time 19.48;Processed batch 4 out of 18; Speed: 16.43 images/sec;
# [STDOUT]                         Projected time: 54.55 seconds
# [STDOUT] Elapsed time 24.36;Processed batch 5 out of 18; Speed: 15.77 images/sec;
# [STDOUT]                         Projected time: 52.77 seconds
# [STDOUT] Elapsed time 29.25;Processed batch 6 out of 18; Speed: 15.32 images/sec;
# [STDOUT]                         Projected time: 50.13 seconds
# [STDOUT] Elapsed time 34.19;Processed batch 7 out of 18; Speed: 14.97 images/sec;
# [STDOUT]                         Projected time: 47.02 seconds
# [STDOUT] Elapsed time 39.11;Processed batch 8 out of 18; Speed: 14.73 images/sec;
# [STDOUT]                         Projected time: 43.45 seconds
# [STDOUT] Elapsed time 44.01;Processed batch 9 out of 18; Speed: 14.54 images/sec;
# [STDOUT]                         Projected time: 39.61 seconds
# [STDOUT] Elapsed time 48.90;Processed batch 10 out of 18; Speed: 14.40 images/sec;
# [STDOUT]                         Projected time: 35.57 seconds
# [STDOUT] Elapsed time 53.80;Processed batch 11 out of 18; Speed: 14.28 images/sec;
# [STDOUT]                         Projected time: 31.38 seconds
# [STDOUT] Elapsed time 58.68;Processed batch 12 out of 18; Speed: 14.18 images/sec;
# [STDOUT]                         Projected time: 27.08 seconds
# [STDOUT] Elapsed time 63.55;Processed batch 13 out of 18; Speed: 14.10 images/sec;
# [STDOUT]                         Projected time: 22.70 seconds
# [STDOUT] Elapsed time 68.41;Processed batch 14 out of 18; Speed: 14.03 images/sec;
# [STDOUT]                         Projected time: 18.24 seconds
# [STDOUT] Elapsed time 73.29;Processed batch 15 out of 18; Speed: 13.97 images/sec;
# [STDOUT]                         Projected time: 13.74 seconds
# [STDOUT] Elapsed time 78.16;Processed batch 16 out of 18; Speed: 13.92 images/sec;
# [STDOUT]                         Projected time: 9.20 seconds
# [STDOUT] Elapsed time 81.21;Processed batch 17 out of 18; Speed: 13.89 images/sec;
# [STDOUT]                         Projected time: 4.51 seconds
# Experiment finished with return code: 0
# Skipping resnet50 as it has already been extracted.

# %%
print(0)
# Out:
# 0

# %% [markdown]
# # reload

# %%
def reload_modules():
    import importlib
    import utils.data_loading as data_loading
    import utils.visualization as visualization
    import utils.dataframes as dataframes
    import utils.utils_transforms as u_transforms
    import utils.training_utils as training_utils
    import utils.model_utils as model_utils
    import utils.file_IO as file_IO
    import utils.vit_rollout_mod as vit_rollout_mod
    import utils.script_launching as script_launching
    
    importlib.reload(file_IO)
    importlib.reload(data_loading)
    importlib.reload(visualization)
    importlib.reload(dataframes)
    importlib.reload(u_transforms)
    importlib.reload(model_utils)
    importlib.reload(training_utils)
    importlib.reload(vit_rollout_mod)
    importlib.reload(script_launching)

    return data_loading, visualization, dataframes, u_transforms, training_utils, model_utils, file_IO, vit_rollout_mod, script_launching
data_loading, visualization, dataframes, u_transforms, training_utils, model_utils, file_IO, vit_rollout_mod, script_launching = reload_modules()
