# %%
import subprocess
import yaml
import os
import sys
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import tempfile

import threading
source_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(source_path)

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import itertools
import random
import numpy as np
import json
import shutil

# %%
model_list = ['logreg','MLPClassifier1','MLPClassifier2']
best_result = [np.inf, np.inf]
all_results = []
label_column='male' #'isEng'#'male'

type_of_search = 'single_search'  # 'grid_search', 'single_search'
pretrain_modality = 'standard'  # 'standard', 'contrastive
train_modality = 'progressive' # 'fine_tune','progressive','from_scratch'
selected_model = 'resnet50' #custom_cnn 'resnet18' #'DeiT-Tiny'  # Example model, can be changed
type_of_model = 'CNN'  # 'CNN', 'Transformer'
huggingface = False #True  # Set to True if using Hugging Face models
use_augmentation = True  # Set to True for data augmentation
augmentation_code='simple_224'#'zoom'  #simple_224
load_data_from = 'pre-processed' #'zarr', 'folder'

selected_classifier = 'MLPClassifier1' #'logreg'
pretrained = False if train_modality == 'from_scratch' else True
use_external_validation = True  # Set to True if using an external validation set
loss_criterion = 'NTXentLoss' if pretrain_modality=='contrastive' else 'CrossEntropyLoss'
val_percentage = 0.2 if pretrain_modality == 'contrastive' else 1.0
use_amp = False

contrastive_mode = True if pretrain_modality == 'contrastive' else False
use_external_validation = True if pretrain_modality == 'contrastive' else use_external_validation

if pretrain_modality == 'contrastive':
    output_dir = source_path+f'\\outputs\\online_deep_feature_extraction\\{selected_model}\\{pretrain_modality}'
else:
    output_dir = source_path+f'\\outputs\\online_deep_feature_extraction\\{selected_model}\\{train_modality}'
file_IO.access_or_create_dir(output_dir)
script_name = source_path+"/scripts/fine-tuning.py"
kind = 'patches_224'  # Example kind, can be changed body, contrastive, patches_224
if pretrain_modality == 'contrastive':
    input_preprocessed=file_IO.load_preprocessed_files(kind, mode='contrastive')
    val_filename = file_IO.load_preprocessed_files(kind, mode='train')
else:
    input_preprocessed=file_IO.load_preprocessed_files(kind, mode='train')
    val_filename = file_IO.load_preprocessed_files(kind, 'val')

model_mode = 'truncated'  # 'truncation', 'full', 'truncated'
truncation='remove head'
custom_transform = False  # Set to True for custom transforms
transform_mode = 'resize'  # 'train', 'val', 'test', 'resize'
n_sub_patches=-1

saved='old-laptop'  # 'new', 'old-laptop', 'new-laptop'
train_df = pd.read_csv(source_path+f'\\outputs\\preprocessed_data\\{input_preprocessed}')
if train_df['file_name'][0].startswith('C'):
    saved = 'new-laptop'

# %% [markdown]
# # preparing layer names

# %%
transform = u_transforms.get_transform(selected_model, use_patches=True, custom=custom_transform, mode=transform_mode)
backbone = model_utils.get_model(name=selected_model, mode=model_mode, pretrained=pretrained, truncation=truncation, 
                                 contrastive=contrastive_mode)
out=model_utils.test_output(224,transform, backbone)
in_features = out.shape[1]
print(f"Model {selected_model} output features: {in_features}")
# Out:
# Model resnet50 output features: 2048

# %%
if contrastive_mode:
    model = backbone
else:
    classificaton_head = model_utils.get_classification_head(selected_classifier,in_features)
    model = model_utils.JoinedModels(backbone, classificaton_head)
    #https://chatgpt.com/share/687124c2-47a8-8010-a4b0-5124a0bf5ecb
#print(model)
all_param_names,backbone_param_names,classifier_param_names = model_utils.get_param_names(model, pretrain_modality)
print(f"Total parameters: {len(all_param_names)}")
print(f"Backbone parameters: {len(backbone_param_names)}")
print(f"Classifier parameters: {len(classifier_param_names)}")
print(f"Backbone parameters: {backbone_param_names}")
# Out:
# Total parameters: 163
# Backbone parameters: 159
# Classifier parameters: 4
# Backbone parameters: ['vision_model.conv1.weight', 'vision_model.bn1.weight', 'vision_model.bn1.bias', 'vision_model.layer1.0.conv1.weight', 'vision_model.layer1.0.bn1.weight', 'vision_model.layer1.0.bn1.bias', 'vision_model.layer1.0.conv2.weight', 'vision_model.layer1.0.bn2.weight', 'vision_model.layer1.0.bn2.bias', 'vision_model.layer1.0.conv3.weight', 'vision_model.layer1.0.bn3.weight', 'vision_model.layer1.0.bn3.bias', 'vision_model.layer1.0.downsample.0.weight', 'vision_model.layer1.0.downsample.1.weight', 'vision_model.layer1.0.downsample.1.bias', 'vision_model.layer1.1.conv1.weight', 'vision_model.layer1.1.bn1.weight', 'vision_model.layer1.1.bn1.bias', 'vision_model.layer1.1.conv2.weight', 'vision_model.layer1.1.bn2.weight', 'vision_model.layer1.1.bn2.bias', 'vision_model.layer1.1.conv3.weight', 'vision_model.layer1.1.bn3.weight', 'vision_model.layer1.1.bn3.bias', 'vision_model.layer1.2.conv1.weight', 'vision_model.layer1.2.bn1.weight', 'vision_model.layer1.2.bn1.bias', 'vision_model.layer1.2.conv2.weight', 'vision_model.layer1.2.bn2.weight', 'vision_model.layer1.2.bn2.bias', 'vision_model.layer1.2.conv3.weight', 'vision_model.layer1.2.bn3.weight', 'vision_model.layer1.2.bn3.bias', 'vision_model.layer2.0.conv1.weight', 'vision_model.layer2.0.bn1.weight', 'vision_model.layer2.0.bn1.bias', 'vision_model.layer2.0.conv2.weight', 'vision_model.layer2.0.bn2.weight', 'vision_model.layer2.0.bn2.bias', 'vision_model.layer2.0.conv3.weight', 'vision_model.layer2.0.bn3.weight', 'vision_model.layer2.0.bn3.bias', 'vision_model.layer2.0.downsample.0.weight', 'vision_model.layer2.0.downsample.1.weight', 'vision_model.layer2.0.downsample.1.bias', 'vision_model.layer2.1.conv1.weight', 'vision_model.layer2.1.bn1.weight', 'vision_model.layer2.1.bn1.bias', 'vision_model.layer2.1.conv2.weight', 'vision_model.layer2.1.bn2.weight', 'vision_model.layer2.1.bn2.bias', 'vision_model.layer2.1.conv3.weight', 'vision_model.layer2.1.bn3.weight', 'vision_model.layer2.1.bn3.bias', 'vision_model.layer2.2.conv1.weight', 'vision_model.layer2.2.bn1.weight', 'vision_model.layer2.2.bn1.bias', 'vision_model.layer2.2.conv2.weight', 'vision_model.layer2.2.bn2.weight', 'vision_model.layer2.2.bn2.bias', 'vision_model.layer2.2.conv3.weight', 'vision_model.layer2.2.bn3.weight', 'vision_model.layer2.2.bn3.bias', 'vision_model.layer2.3.conv1.weight', 'vision_model.layer2.3.bn1.weight', 'vision_model.layer2.3.bn1.bias', 'vision_model.layer2.3.conv2.weight', 'vision_model.layer2.3.bn2.weight', 'vision_model.layer2.3.bn2.bias', 'vision_model.layer2.3.conv3.weight', 'vision_model.layer2.3.bn3.weight', 'vision_model.layer2.3.bn3.bias', 'vision_model.layer3.0.conv1.weight', 'vision_model.layer3.0.bn1.weight', 'vision_model.layer3.0.bn1.bias', 'vision_model.layer3.0.conv2.weight', 'vision_model.layer3.0.bn2.weight', 'vision_model.layer3.0.bn2.bias', 'vision_model.layer3.0.conv3.weight', 'vision_model.layer3.0.bn3.weight', 'vision_model.layer3.0.bn3.bias', 'vision_model.layer3.0.downsample.0.weight', 'vision_model.layer3.0.downsample.1.weight', 'vision_model.layer3.0.downsample.1.bias', 'vision_model.layer3.1.conv1.weight', 'vision_model.layer3.1.bn1.weight', 'vision_model.layer3.1.bn1.bias', 'vision_model.layer3.1.conv2.weight', 'vision_model.layer3.1.bn2.weight', 'vision_model.layer3.1.bn2.bias', 'vision_model.layer3.1.conv3.weight', 'vision_model.layer3.1.bn3.weight', 'vision_model.layer3.1.bn3.bias', 'vision_model.layer3.2.conv1.weight', 'vision_model.layer3.2.bn1.weight', 'vision_model.layer3.2.bn1.bias', 'vision_model.layer3.2.conv2.weight', 'vision_model.layer3.2.bn2.weight', 'vision_model.layer3.2.bn2.bias', 'vision_model.layer3.2.conv3.weight', 'vision_model.layer3.2.bn3.weight', 'vision_model.layer3.2.bn3.bias', 'vision_model.layer3.3.conv1.weight', 'vision_model.layer3.3.bn1.weight', 'vision_model.layer3.3.bn1.bias', 'vision_model.layer3.3.conv2.weight', 'vision_model.layer3.3.bn2.weight', 'vision_model.layer3.3.bn2.bias', 'vision_model.layer3.3.conv3.weight', 'vis ...

# %%
print(f"All parameters: {all_param_names}")
# Out:
# All parameters: ['vision_model.conv1.weight', 'vision_model.bn1.weight', 'vision_model.bn1.bias', 'vision_model.layer1.0.conv1.weight', 'vision_model.layer1.0.bn1.weight', 'vision_model.layer1.0.bn1.bias', 'vision_model.layer1.0.conv2.weight', 'vision_model.layer1.0.bn2.weight', 'vision_model.layer1.0.bn2.bias', 'vision_model.layer1.0.conv3.weight', 'vision_model.layer1.0.bn3.weight', 'vision_model.layer1.0.bn3.bias', 'vision_model.layer1.0.downsample.0.weight', 'vision_model.layer1.0.downsample.1.weight', 'vision_model.layer1.0.downsample.1.bias', 'vision_model.layer1.1.conv1.weight', 'vision_model.layer1.1.bn1.weight', 'vision_model.layer1.1.bn1.bias', 'vision_model.layer1.1.conv2.weight', 'vision_model.layer1.1.bn2.weight', 'vision_model.layer1.1.bn2.bias', 'vision_model.layer1.1.conv3.weight', 'vision_model.layer1.1.bn3.weight', 'vision_model.layer1.1.bn3.bias', 'vision_model.layer1.2.conv1.weight', 'vision_model.layer1.2.bn1.weight', 'vision_model.layer1.2.bn1.bias', 'vision_model.layer1.2.conv2.weight', 'vision_model.layer1.2.bn2.weight', 'vision_model.layer1.2.bn2.bias', 'vision_model.layer1.2.conv3.weight', 'vision_model.layer1.2.bn3.weight', 'vision_model.layer1.2.bn3.bias', 'vision_model.layer2.0.conv1.weight', 'vision_model.layer2.0.bn1.weight', 'vision_model.layer2.0.bn1.bias', 'vision_model.layer2.0.conv2.weight', 'vision_model.layer2.0.bn2.weight', 'vision_model.layer2.0.bn2.bias', 'vision_model.layer2.0.conv3.weight', 'vision_model.layer2.0.bn3.weight', 'vision_model.layer2.0.bn3.bias', 'vision_model.layer2.0.downsample.0.weight', 'vision_model.layer2.0.downsample.1.weight', 'vision_model.layer2.0.downsample.1.bias', 'vision_model.layer2.1.conv1.weight', 'vision_model.layer2.1.bn1.weight', 'vision_model.layer2.1.bn1.bias', 'vision_model.layer2.1.conv2.weight', 'vision_model.layer2.1.bn2.weight', 'vision_model.layer2.1.bn2.bias', 'vision_model.layer2.1.conv3.weight', 'vision_model.layer2.1.bn3.weight', 'vision_model.layer2.1.bn3.bias', 'vision_model.layer2.2.conv1.weight', 'vision_model.layer2.2.bn1.weight', 'vision_model.layer2.2.bn1.bias', 'vision_model.layer2.2.conv2.weight', 'vision_model.layer2.2.bn2.weight', 'vision_model.layer2.2.bn2.bias', 'vision_model.layer2.2.conv3.weight', 'vision_model.layer2.2.bn3.weight', 'vision_model.layer2.2.bn3.bias', 'vision_model.layer2.3.conv1.weight', 'vision_model.layer2.3.bn1.weight', 'vision_model.layer2.3.bn1.bias', 'vision_model.layer2.3.conv2.weight', 'vision_model.layer2.3.bn2.weight', 'vision_model.layer2.3.bn2.bias', 'vision_model.layer2.3.conv3.weight', 'vision_model.layer2.3.bn3.weight', 'vision_model.layer2.3.bn3.bias', 'vision_model.layer3.0.conv1.weight', 'vision_model.layer3.0.bn1.weight', 'vision_model.layer3.0.bn1.bias', 'vision_model.layer3.0.conv2.weight', 'vision_model.layer3.0.bn2.weight', 'vision_model.layer3.0.bn2.bias', 'vision_model.layer3.0.conv3.weight', 'vision_model.layer3.0.bn3.weight', 'vision_model.layer3.0.bn3.bias', 'vision_model.layer3.0.downsample.0.weight', 'vision_model.layer3.0.downsample.1.weight', 'vision_model.layer3.0.downsample.1.bias', 'vision_model.layer3.1.conv1.weight', 'vision_model.layer3.1.bn1.weight', 'vision_model.layer3.1.bn1.bias', 'vision_model.layer3.1.conv2.weight', 'vision_model.layer3.1.bn2.weight', 'vision_model.layer3.1.bn2.bias', 'vision_model.layer3.1.conv3.weight', 'vision_model.layer3.1.bn3.weight', 'vision_model.layer3.1.bn3.bias', 'vision_model.layer3.2.conv1.weight', 'vision_model.layer3.2.bn1.weight', 'vision_model.layer3.2.bn1.bias', 'vision_model.layer3.2.conv2.weight', 'vision_model.layer3.2.bn2.weight', 'vision_model.layer3.2.bn2.bias', 'vision_model.layer3.2.conv3.weight', 'vision_model.layer3.2.bn3.weight', 'vision_model.layer3.2.bn3.bias', 'vision_model.layer3.3.conv1.weight', 'vision_model.layer3.3.bn1.weight', 'vision_model.layer3.3.bn1.bias', 'vision_model.layer3.3.conv2.weight', 'vision_model.layer3.3.bn2.weight', 'vision_model.layer3.3.bn2.bias', 'vision_model.layer3.3.conv3.weight', 'vision_m ...

# %% [markdown]
# # launch fine-tuning

# %%
clear_directory = True  # Set to True to clear the directory before saving checkpoints
total_epochs = 150  # Total number of epochs for fine-tuning
patience=150
steps=training_utils.get_progressive_training_steps(selected_model,False) #rewrite the function to take a string instead of load_contrastive=True/False
param_grid=training_utils.get_search_params(type_of_search=type_of_search, type_of_training=train_modality, type_of_model=type_of_model)
#print(param_grid)

keys, values = zip(*param_grid.items())
all_combos = list(itertools.product(*values))

# Shuffle combinations
if type_of_search == 'random_search':
    random.shuffle(all_combos) 
    # Pick N random samples (e.g., 5)
    N = 30 if 30 < len(all_combos) else len(all_combos)
    experiments = all_combos[:N]
else:
    # For grid search, use all combinations
    experiments = all_combos[:]


save_common=output_dir
prev_log = os.path.join(save_common, f'{type_of_search}_results.csv')
if os.path.exists(prev_log):
    prev_results = pd.read_csv(prev_log)
    print(prev_results['best_val_loss'].min())
    print(prev_results.iloc[prev_results['best_val_loss'].idxmin()])
    #display(prev_results.iloc[prev_results['best_val_loss'].idxmin()])
    #print(prev_results['id'])
    for model in model_list:

        model_results = prev_results[prev_results['head_model'] == model]
        if not model_results.empty:
            best_result_temp = model_results['best_val_loss'].min()
            print(f"Best result for {model}: {best_result_temp}")
            best_result[model_list.index(model)]= best_result_temp
        else:
            print(f"No results found for model: {model}")
    last_index = prev_results['id'].max() if not prev_results.empty else 0
else:
    prev_results = None
    last_index = None
print(best_result)
print(f"Last index: {last_index}")
print(type_of_search)
# Out:
# [inf, inf]
# Last index: None
# single_search

# %%
start = last_index + 1 if last_index is not None else 0
start = 0
for i, combo in enumerate(experiments[start:]):
    experiment_dict = dict(zip(keys, combo))
    experiment_dict['id'] = i+start
    model_name = experiment_dict['head_model']
    save_path = output_dir
    file_IO.access_or_create_dir(save_path)
    checkpoint_path=save_path+'\\checkpoints'
    file_IO.access_or_create_dir(checkpoint_path)
    if clear_directory==True:
        print(f'Clearing directory: {checkpoint_path}')
        file_IO.clear_folder(checkpoint_path)

    log_grad_norm = experiment_dict['log_grad_norm']
    optim_config = training_utils.set_search_params(experiment_dict,train_modality,total_epochs,steps,backbone_param_names,classifier_param_names)
    nn_parameters={
        'dropout': experiment_dict['dropout'],
        'n_neurons': experiment_dict['n_neurons'],
        'activation': experiment_dict.get('activation', 'relu'),  # Default to 'relu' if not specified
        'with_input_norm': experiment_dict.get('with_input_norm', None),  # Default to True if not specified
    }

    args = script_launching.DotDict(
        label_column=label_column,
        N_max=-1,
        patches=True,
        input_filename=input_preprocessed,
        val_filename=val_filename if use_external_validation else None,
        huggingface=huggingface,
        pooling=False,  # if true in transformer models use pooling, if false only the cls token
        custom_transform=custom_transform,  # custom transform for the dataset
        transform_mode=transform_mode,  # 'train', 'val', 'test'
        save_h5=False,
        selected_model=selected_model,  # googlenet, alexnet
        selected_classifier=selected_classifier,  # 'logreg', 'svm', 'rf', 'gbc', 'mlp', 'dt'
        truncation=truncation,
        running='new-laptop',
        saved=saved,
        model_mode=model_mode,  # 'truncation
        batch_size=64,
        select_cls=False,
        num_workers=4,
        pin_memory=True,
        show_image=False,
        checkpoint_path = checkpoint_path+"\\checkpoint.pt",
        save_path = save_path,
        total_epochs = total_epochs,
        log_grad_norm = log_grad_norm,
        use_profiler = False,
        run_epochs = total_epochs,
        plot_every = 1,
        patience = patience,
        use_amp = use_amp ,#mixed precision training,
        val_percentage= val_percentage ,#percentage of validation data used for linear evaluation,
        n_splits = 4,
        loss_criterion = loss_criterion,
        optim_config = optim_config,
        use_augmentation=use_augmentation,  # Set to True for data augmentation
        augmentation_code=augmentation_code,  # 'simple', 'full'
        n_patches=n_sub_patches,
        contrastive_mode=contrastive_mode,  # Set to True for contrastive learning
        nn_parameters=nn_parameters,  # Dictionary with neural network parameters
        type_of_search=type_of_search,  # 'grid_search', 'single_search'
        train_modality=train_modality,  # 'fine_tune', 'progressive', 'from_scratch'
        pretrain_modality=pretrain_modality,  # 'standard', 'contrastive'
        load_data_from=load_data_from,  # 'zarr', 'folder'
        pretrained=pretrained,  # True or False
    )
    file_IO.save_args(args,checkpoint_path)  # Save the arguments to a file

    script_launching.run_experiment_threaded(args,script_name)  # Test a single run first

    with open(os.path.join(save_path, "best_model_performance_temp.json"), "r") as f:
        best_model_performance = json.load(f)

    for key in experiment_dict.keys():
        if key not in best_model_performance:
            best_model_performance[key] = experiment_dict[key]
    all_results.append(best_model_performance)

    index=model_list.index(model_name)
    if best_model_performance['best_val_loss'] < best_result[index]:
        best_checkpoint = os.path.join(checkpoint_path, "checkpoint_best.pt")
        destination = os.path.join(save_path, "checkpoint_best.pt")
        shutil.copy2(best_checkpoint, destination)
        best = os.path.join(checkpoint_path, "training_plot.png")
        destination = os.path.join(save_path, "training_plot.png")
        shutil.copy2(best, destination)
        best = os.path.join(checkpoint_path, "args.txt")
        destination = os.path.join(save_path, "args.txt")
        shutil.copy2(best, destination)
        best_result[index] = best_model_performance['best_val_loss']

    all_results_df = pd.DataFrame(all_results)
    if prev_results is not None:
        all_results_df = pd.concat([prev_results, all_results_df], ignore_index=True)
    all_results_df.to_csv(os.path.join(save_common, f'{type_of_search}_results.csv'), index=False)
# Out:
# Clearing directory: c:\Users\andre\VsCode\PD related projects\gender_detection\outputs\online_deep_feature_extraction\resnet50\progressive\checkpoints
# Starting experiment:
# [STDOUT] Output shape:  torch.Size([1, 2048])
# [STDOUT] tensor([[ 0.0920, -0.0372]])
# [STDOUT] Device is:  cuda
# [STDOUT] Compose(
# [STDOUT]     RandomApply(
# [STDOUT]     p=0.2
# [STDOUT]     RandomResizedCrop(size=(224, 224), scale=(0.6, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear, antialias=True)
# [STDOUT] )
# [STDOUT]     RandomHorizontalFlip(p=0.2)
# [STDOUT]     RandomVerticalFlip(p=0.2)
# [STDOUT] )
# [STDOUT] None
# [STDOUT] Train dataset size: 56400
# [STDOUT] Validation dataset size: 14200
# [STDOUT] [GPU Memory] Allocated: 0.00 MB | Reserved: 0.00 MB
# [STDERR] 2025-10-23 13:15:06,836 - INFO - Model size: 94.88 MB
# [STDERR] INFO:train_logger:Model size: 94.88 MB
# [STDOUT] 📂 No checkpoint found at c:\Users\andre\VsCode\PD related projects\gender_detection\outputs\online_deep_feature_extraction\resnet50\progressive\checkpoints\checkpoint.pt. Starting fresh training.
# [STDERR] 2025-10-23 13:15:06,845 - INFO - Setting up training modality: progressive
# [STDERR] INFO:train_logger:Setting up training modality: progressive
# [STDERR] 2025-10-23 13:15:06,845 - INFO - Setting optimizer: AdamW
# [STDERR] INFO:train_logger:Setting optimizer: AdamW
# [STDERR] 2025-10-23 13:15:06,845 - INFO -
# [STDERR] Epoch 0 - Optimization Phase: 0
# [STDERR] INFO:train_logger:
# [STDERR] Epoch 0 - Optimization Phase: 0
# [STDERR]
# [STDERR] Epoch 1/150 [Train]:   0%|          | 0/882 [00:00<?, ?it/s]
# [STDERR] Epoch 1/150 [Train]:   0%|          | 1/882 [00:33<8:18:30, 33.95s/it]
# [STDERR] Epoch 1/150 [Train]:   0%|          | 2/882 [00:34<3:28:24, 14.21s/it]
# [STDERR] Epoch 1/150 [Train]:   0%|          | 3/882 [00:34<1:55:50,  7.91s/it]
# [STDERR] Epoch 1/150 [Train]:   0%|          | 4/882 [00:35<1:12:15,  4.94s/it]
# [STDERR] Epoch 1/150 [Train]:   1%|          | 5/882 [00:35<48:26,  3.31s/it]
# [STDERR] Epoch 1/150 [Train]:   1%|          | 6/882 [00:36<35:21,  2.42s/it]
# [STDERR] Epoch 1/150 [Train]:   1%|          | 7/882 [00:36<26:02,  1.79s/it]
# [STDERR] Epoch 1/150 [Train]:   1%|          | 8/882 [00:37<19:35,  1.34s/it]
# [STDERR] Epoch 1/150 [Train]:   1%|          | 9/882 [00:37<15:21,  1.06s/it]
# [STDERR] Epoch 1/150 [Train]:   1%|          | 10/882 [00:38<13:32,  1.07it/s]
# [STDERR] Epoch 1/150 [Train]:   1%|          | 11/882 [00:38<11:57,  1.21it/s]
# [STDERR] Epoch 1/150 [Train]:   1%|▏         | 12/882 [00:39<11:19,  1.28it/s]
# [STDERR] Epoch 1/150 [Train]:   1%|▏         | 13/882 [00:40<10:22,  1.40it/s]
# [STDERR] Epoch 1/150 [Train]:   2%|▏         | 14/882 [00:40<08:58,  1.61it/s]
# [STDERR] Epoch 1/150 [Train]:   2%|▏         | 15/882 [00:40<07:58,  1.81it/s]
# [STDERR] Epoch 1/150 [Train]:   2%|▏         | 16/882 [00:41<07:18,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:   2%|▏         | 17/882 [00:41<06:54,  2.09it/s]
# [STDERR] Epoch 1/150 [Train]:   2%|▏         | 18/882 [00:42<06:35,  2.18it/s]
# [STDERR] Epoch 1/150 [Train]:   2%|▏         | 19/882 [00:42<06:20,  2.27it/s]
# [STDERR] Epoch 1/150 [Train]:   2%|▏         | 20/882 [00:42<06:08,  2.34it/s]
# [STDERR] Epoch 1/150 [Train]:   2%|▏         | 21/882 [00:43<06:03,  2.37it/s]
# [STDERR] Epoch 1/150 [Train]:   2%|▏         | 22/882 [00:43<06:00,  2.38it/s]
# [STDERR] Epoch 1/150 [Train]:   3%|▎         | 23/882 [00:44<05:54,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:   3%|▎         | 24/882 [00:44<05:49,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:   3%|▎         | 25/882 [00:44<05:54,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:   3%|▎         | 26/882 [00:45<05:52,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:   3%|▎         | 27/882 [00:45<05:47,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:   3%|▎         | 28/882 [00:46<05:56,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:   3%|▎         | 29/882 [00:46<05:53,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:   3%|▎         | 30/882 [00:46<05:48,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   4%|▎         | 31/882 [00:47<05:51,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:   4%|▎         | 32/882 [00:47<05:53,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:   4%|▎         | 33/882 [00:48<06:03,  2.33it/s]
# [STDERR] Epoch 1/150 [Train]:   4%|▍         | 34/882 [00:48<06:01,  2.35it/s]
# [STDERR] Epoch 1/150 [Train]:   4%|▍         | 35/882 [00:49<05:58,  2.36it/s]
# [STDERR] Epoch 1/150 [Train]:   4%|▍         | 36/882 [00:49<06:28,  2.18it/s]
# [STDERR] Epoch 1/150 [Train]:   4%|▍         | 37/882 [00:50<06:13,  2.26it/s]
# [STDERR] Epoch 1/150 [Train]:   4%|▍         | 38/882 [00:50<06:02,  2.33it/s]
# [STDERR] Epoch 1/150 [Train]:   4%|▍         | 39/882 [00:50<05:50,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:   5%|▍         | 40/882 [00:51<05:52,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:   5%|▍         | 41/882 [00:51<05:52,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:   5%|▍         | 42/882 [00:52<05:43,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   5%|▍         | 43/882 [00:52<05:47,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:   5%|▍         | 44/882 [00:52<05:57,  2.35it/s]
# [STDERR] Epoch 1/150 [Train]:   5%|▌         | 45/882 [00:53<05:54,  2.36it/s]
# [STDERR] Epoch 1/150 [Train]:   5%|▌         | 46/882 [00:53<05:58,  2.33it/s]
# [STDERR] Epoch 1/150 [Train]:   5%|▌         | 47/882 [00:54<05:50,  2.38it/s]
# [STDERR] Epoch 1/150 [Train]:   5%|▌         | 48/882 [00:54<05:47,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:   6%|▌         | 49/882 [00:54<05:41,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   6%|▌         | 50/882 [00:55<05:47,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:   6%|▌         | 51/882 [00:55<05:44,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:   6%|▌         | 52/882 [00:56<05:42,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:   6%|▌         | 53/882 [00:56<05:37,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:   6%|▌         | 54/882 [00:57<05:39,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   6%|▌         | 55/882 [00:57<05:48,  2.37it/s]
# [STDERR] Epoch 1/150 [Train]:   6%|▋         | 56/882 [00:57<05:39,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:   6%|▋         | 57/882 [00:58<05:37,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   7%|▋         | 58/882 [00:58<05:41,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:   7%|▋         | 59/882 [00:59<05:43,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:   7%|▋         | 60/882 [00:59<05:37,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   7%|▋         | 61/882 [00:59<05:35,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:   7%|▋         | 62/882 [01:00<05:35,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   7%|▋         | 63/882 [01:00<05:40,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:   7%|▋         | 64/882 [01:01<05:54,  2.30it/s]
# [STDERR] Epoch 1/150 [Train]:   7%|▋         | 65/882 [01:01<06:16,  2.17it/s]
# [STDERR] Epoch 1/150 [Train]:   7%|▋         | 66/882 [01:02<06:00,  2.26it/s]
# [STDERR] Epoch 1/150 [Train]:   8%|▊         | 67/882 [01:02<05:49,  2.33it/s]
# [STDERR] Epoch 1/150 [Train]:   8%|▊         | 68/882 [01:02<05:45,  2.36it/s]
# [STDERR] Epoch 1/150 [Train]:   8%|▊         | 69/882 [01:03<05:38,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:   8%|▊         | 70/882 [01:03<05:39,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:   8%|▊         | 71/882 [01:04<05:42,  2.37it/s]
# [STDERR] Epoch 1/150 [Train]:   8%|▊         | 72/882 [01:04<05:33,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:   8%|▊         | 73/882 [01:05<05:37,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:   8%|▊         | 74/882 [01:05<05:34,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:   9%|▊         | 75/882 [01:05<05:30,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   9%|▊         | 76/882 [01:06<05:26,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:   9%|▊         | 77/882 [01:06<05:27,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:   9%|▉         | 78/882 [01:07<05:27,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:   9%|▉         | 79/882 [01:07<05:30,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:   9%|▉         | 80/882 [01:07<05:28,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   9%|▉         | 81/882 [01:08<05:26,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:   9%|▉         | 82/882 [01:08<05:28,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:   9%|▉         | 83/882 [01:09<06:00,  2.22it/s]
# [STDERR] Epoch 1/150 [Train]:  10%|▉         | 84/882 [01:09<05:46,  2.30it/s]
# [STDERR] Epoch 1/150 [Train]:  10%|▉         | 85/882 [01:10<05:36,  2.37it/s]
# [STDERR] Epoch 1/150 [Train]:  10%|▉         | 86/882 [01:10<05:29,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:  10%|▉         | 87/882 [01:10<05:24,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  10%|▉         | 88/882 [01:11<05:20,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  10%|█         | 89/882 [01:11<05:19,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  10%|█         | 90/882 [01:12<05:18,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  10%|█         | 91/882 [01:12<05:16,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  10%|█         | 92/882 [01:12<05:15,  2.51it/s]
# [STDERR] Epoch 1/150 [Train]:  11%|█         | 93/882 [01:13<05:22,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  11%|█         | 94/882 [01:13<05:25,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:  11%|█         | 95/882 [01:14<05:19,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  11%|█         | 96/882 [01:14<05:15,  2.49it/s]
# [STDERR] Epoch 1/150 [Train]:  11%|█         | 97/882 [01:14<05:20,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  11%|█         | 98/882 [01:15<05:24,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:  11%|█         | 99/882 [01:15<05:22,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  11%|█▏        | 100/882 [01:16<05:17,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  11%|█▏        | 101/882 [01:16<05:12,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  12%|█▏        | 102/882 [01:16<05:12,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  12%|█▏        | 103/882 [01:17<05:09,  2.51it/s]
# [STDERR] Epoch 1/150 [Train]:  12%|█▏        | 104/882 [01:17<05:11,  2.49it/s]
# [STDERR] Epoch 1/150 [Train]:  12%|█▏        | 105/882 [01:18<05:13,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  12%|█▏        | 106/882 [01:18<05:12,  2.49it/s]
# [STDERR] Epoch 1/150 [Train]:  12%|█▏        | 107/882 [01:18<05:14,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  12%|█▏        | 108/882 [01:19<05:10,  2.49it/s]
# [STDERR] Epoch 1/150 [Train]:  12%|█▏        | 109/882 [01:19<05:07,  2.51it/s]
# [STDERR] Epoch 1/150 [Train]:  12%|█▏        | 110/882 [01:20<05:11,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  13%|█▎        | 111/882 [01:20<05:16,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  13%|█▎        | 112/882 [01:20<05:15,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  13%|█▎        | 113/882 [01:21<05:12,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  13%|█▎        | 114/882 [01:21<05:10,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  13%|█▎        | 115/882 [01:22<05:14,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  13%|█▎        | 116/882 [01:22<05:10,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  13%|█▎        | 117/882 [01:23<05:18,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:  13%|█▎        | 118/882 [01:23<05:40,  2.24it/s]
# [STDERR] Epoch 1/150 [Train]:  13%|█▎        | 119/882 [01:23<05:33,  2.29it/s]
# [STDERR] Epoch 1/150 [Train]:  14%|█▎        | 120/882 [01:24<05:24,  2.35it/s]
# [STDERR] Epoch 1/150 [Train]:  14%|█▎        | 121/882 [01:24<05:16,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:  14%|█▍        | 122/882 [01:25<05:13,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:  14%|█▍        | 123/882 [01:25<05:19,  2.37it/s]
# [STDERR] Epoch 1/150 [Train]:  14%|█▍        | 124/882 [01:26<05:23,  2.35it/s]
# [STDERR] Epoch 1/150 [Train]:  14%|█▍        | 125/882 [01:26<05:15,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:  14%|█▍        | 126/882 [01:26<05:10,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  14%|█▍        | 127/882 [01:27<05:08,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  15%|█▍        | 128/882 [01:27<05:14,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:  15%|█▍        | 129/882 [01:28<05:14,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:  15%|█▍        | 130/882 [01:28<05:13,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:  15%|█▍        | 131/882 [01:28<05:12,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:  15%|█▍        | 132/882 [01:29<05:09,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:  15%|█▌        | 133/882 [01:29<05:05,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  15%|█▌        | 134/882 [01:30<05:07,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  15%|█▌        | 135/882 [01:30<05:12,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:  15%|█▌        | 136/882 [01:30<05:04,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  16%|█▌        | 137/882 [01:31<05:05,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  16%|█▌        | 138/882 [01:31<05:14,  2.37it/s]
# [STDERR] Epoch 1/150 [Train]:  16%|█▌        | 139/882 [01:32<05:09,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:  16%|█▌        | 140/882 [01:32<05:04,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  16%|█▌        | 141/882 [01:33<05:12,  2.37it/s]
# [STDERR] Epoch 1/150 [Train]:  16%|█▌        | 142/882 [01:33<05:11,  2.38it/s]
# [STDERR] Epoch 1/150 [Train]:  16%|█▌        | 143/882 [01:33<05:11,  2.37it/s]
# [STDERR] Epoch 1/150 [Train]:  16%|█▋        | 144/882 [01:34<05:04,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  16%|█▋        | 145/882 [01:34<05:00,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  17%|█▋        | 146/882 [01:35<04:56,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  17%|█▋        | 147/882 [01:35<04:53,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  17%|█▋        | 148/882 [01:35<04:53,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  17%|█▋        | 149/882 [01:36<04:51,  2.52it/s]
# [STDERR] Epoch 1/150 [Train]:  17%|█▋        | 150/882 [01:36<04:50,  2.52it/s]
# [STDERR] Epoch 1/150 [Train]:  17%|█▋        | 151/882 [01:37<04:49,  2.52it/s]
# [STDERR] Epoch 1/150 [Train]:  17%|█▋        | 152/882 [01:37<04:48,  2.53it/s]
# [STDERR] Epoch 1/150 [Train]:  17%|█▋        | 153/882 [01:37<04:46,  2.54it/s]
# [STDERR] Epoch 1/150 [Train]:  17%|█▋        | 154/882 [01:38<04:46,  2.54it/s]
# [STDERR] Epoch 1/150 [Train]:  18%|█▊        | 155/882 [01:38<04:49,  2.51it/s]
# [STDERR] Epoch 1/150 [Train]:  18%|█▊        | 156/882 [01:39<04:49,  2.51it/s]
# [STDERR] Epoch 1/150 [Train]:  18%|█▊        | 157/882 [01:39<04:54,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  18%|█▊        | 158/882 [01:39<04:51,  2.49it/s]
# [STDERR] Epoch 1/150 [Train]:  18%|█▊        | 159/882 [01:40<04:52,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  18%|█▊        | 160/882 [01:40<04:50,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  18%|█▊        | 161/882 [01:41<04:49,  2.49it/s]
# [STDERR] Epoch 1/150 [Train]:  18%|█▊        | 162/882 [01:41<05:03,  2.38it/s]
# [STDERR] Epoch 1/150 [Train]:  18%|█▊        | 163/882 [01:41<04:58,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:  19%|█▊        | 164/882 [01:42<04:55,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  19%|█▊        | 165/882 [01:42<04:51,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  19%|█▉        | 166/882 [01:43<04:48,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  19%|█▉        | 167/882 [01:43<04:46,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  19%|█▉        | 168/882 [01:43<04:45,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  19%|█▉        | 169/882 [01:44<04:50,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  19%|█▉        | 170/882 [01:44<04:48,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:  19%|█▉        | 171/882 [01:45<04:44,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  20%|█▉        | 172/882 [01:45<04:44,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  20%|█▉        | 173/882 [01:45<04:43,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  20%|█▉        | 174/882 [01:46<04:49,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  20%|█▉        | 175/882 [01:46<04:48,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  20%|█▉        | 176/882 [01:47<04:49,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  20%|██        | 177/882 [01:47<04:56,  2.38it/s]
# [STDERR] Epoch 1/150 [Train]:  20%|██        | 178/882 [01:48<04:53,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:  20%|██        | 179/882 [01:48<04:48,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  20%|██        | 180/882 [01:48<04:44,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  21%|██        | 181/882 [01:49<04:48,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  21%|██        | 182/882 [01:49<04:48,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  21%|██        | 183/882 [01:50<04:49,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:  21%|██        | 184/882 [01:50<04:51,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:  21%|██        | 185/882 [01:50<04:47,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:  21%|██        | 186/882 [01:51<04:44,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  21%|██        | 187/882 [01:51<04:42,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  21%|██▏       | 188/882 [01:52<04:40,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:  21%|██▏       | 189/882 [01:52<04:41,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  22%|██▏       | 190/882 [01:52<04:40,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:  22%|██▏       | 191/882 [01:53<04:43,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  22%|██▏       | 192/882 [01:53<04:40,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  22%|██▏       | 193/882 [01:54<04:43,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  22%|██▏       | 194/882 [01:54<04:48,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:  22%|██▏       | 195/882 [01:55<04:45,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:  22%|██▏       | 196/882 [01:55<04:41,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  22%|██▏       | 197/882 [01:55<04:39,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  22%|██▏       | 198/882 [01:56<04:40,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  23%|██▎       | 199/882 [01:56<04:37,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  23%|██▎       | 200/882 [01:57<04:37,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  23%|██▎       | 201/882 [01:57<04:37,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  23%|██▎       | 202/882 [01:57<04:37,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  23%|██▎       | 203/882 [01:58<04:37,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  23%|██▎       | 204/882 [01:58<04:36,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  23%|██▎       | 205/882 [01:59<04:38,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  23%|██▎       | 206/882 [01:59<04:37,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  23%|██▎       | 207/882 [01:59<04:34,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  24%|██▎       | 208/882 [02:00<04:31,  2.49it/s]
# [STDERR] Epoch 1/150 [Train]:  24%|██▎       | 209/882 [02:00<04:31,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:  24%|██▍       | 210/882 [02:01<04:34,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  24%|██▍       | 211/882 [02:01<04:32,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:  24%|██▍       | 212/882 [02:01<04:30,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  24%|██▍       | 213/882 [02:02<04:32,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  24%|██▍       | 214/882 [02:02<04:32,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  24%|██▍       | 215/882 [02:03<04:28,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  24%|██▍       | 216/882 [02:03<04:29,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:  25%|██▍       | 217/882 [02:03<04:34,  2.42it/s]
# [STDERR] Epoch 1/150 [Train]:  25%|██▍       | 218/882 [02:04<04:31,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  25%|██▍       | 219/882 [02:04<04:28,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:  25%|██▍       | 220/882 [02:05<04:26,  2.48it/s]
# [STDERR] Epoch 1/150 [Train]:  25%|██▌       | 221/882 [02:05<04:46,  2.31it/s]
# [STDERR] Epoch 1/150 [Train]:  25%|██▌       | 222/882 [02:06<04:41,  2.34it/s]
# [STDERR] Epoch 1/150 [Train]:  25%|██▌       | 223/882 [02:06<04:35,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:  25%|██▌       | 224/882 [02:06<04:33,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:  26%|██▌       | 225/882 [02:07<04:36,  2.37it/s]
# [STDERR] Epoch 1/150 [Train]:  26%|██▌       | 226/882 [02:07<04:41,  2.33it/s]
# [STDERR] Epoch 1/150 [Train]:  26%|██▌       | 227/882 [02:08<04:35,  2.38it/s]
# [STDERR] Epoch 1/150 [Train]:  26%|██▌       | 228/882 [02:08<04:31,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:  26%|██▌       | 229/882 [02:08<04:31,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:  26%|██▌       | 230/882 [02:09<04:32,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:  26%|██▌       | 231/882 [02:09<04:33,  2.38it/s]
# [STDERR] Epoch 1/150 [Train]:  26%|██▋       | 232/882 [02:10<04:29,  2.41it/s]
# [STDERR] Epoch 1/150 [Train]:  26%|██▋       | 233/882 [02:10<04:25,  2.44it/s]
# [STDERR] Epoch 1/150 [Train]:  27%|██▋       | 234/882 [02:11<04:26,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  27%|██▋       | 235/882 [02:11<04:24,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  27%|██▋       | 236/882 [02:11<04:21,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:  27%|██▋       | 237/882 [02:12<04:20,  2.47it/s]
# [STDERR] Epoch 1/150 [Train]:  27%|██▋       | 238/882 [02:12<04:18,  2.49it/s]
# [STDERR] Epoch 1/150 [Train]:  27%|██▋       | 239/882 [02:13<04:17,  2.50it/s]
# [STDERR] Epoch 1/150 [Train]:  27%|██▋       | 240/882 [02:13<04:15,  2.52it/s]
# [STDERR] Epoch 1/150 [Train]:  27%|██▋       | 241/882 [02:13<04:28,  2.39it/s]
# [STDERR] Epoch 1/150 [Train]:  27%|██▋       | 242/882 [02:14<04:26,  2.40it/s]
# [STDERR] Epoch 1/150 [Train]:  28%|██▊       | 243/882 [02:14<04:23,  2.43it/s]
# [STDERR] Epoch 1/150 [Train]:  28%|██▊       | 244/882 [02:15<04:20,  2.45it/s]
# [STDERR] Epoch 1/150 [Train]:  28%|██▊       | 245/882 [02:15<04:19,  2.46it/s]
# [STDERR] Epoch 1/150 [Train]:  28%|██▊       | 246/882 [02:16<04:36,  2.30it/s]
# [STDERR] Epoch 1/150 [Train]:  28%|██▊       | 247/882 [02:16<05:09,  2.05it/s]
# [STDERR] Epoch 1/150 [Train]:  28%|██▊       | 248/882 [02:17<05:13,  2.02it/s]
# [STDERR] Epoch 1/150 [Train]:  28%|██▊       | 249/882 [02:17<05:20,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  28%|██▊       | 250/882 [02:18<05:25,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  28%|██▊       | 251/882 [02:18<05:26,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  29%|██▊       | 252/882 [02:19<05:23,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  29%|██▊       | 253/882 [02:19<05:21,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  29%|██▉       | 254/882 [02:20<05:23,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  29%|██▉       | 255/882 [02:20<05:23,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  29%|██▉       | 256/882 [02:21<05:20,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  29%|██▉       | 257/882 [02:21<05:21,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  29%|██▉       | 258/882 [02:22<05:22,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  29%|██▉       | 259/882 [02:22<05:25,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  29%|██▉       | 260/882 [02:23<05:23,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  30%|██▉       | 261/882 [02:23<05:21,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  30%|██▉       | 262/882 [02:24<05:19,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  30%|██▉       | 263/882 [02:24<05:17,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  30%|██▉       | 264/882 [02:25<05:17,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  30%|███       | 265/882 [02:25<05:16,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  30%|███       | 266/882 [02:26<05:16,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  30%|███       | 267/882 [02:26<05:15,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  30%|███       | 268/882 [02:27<05:15,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  30%|███       | 269/882 [02:27<05:14,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  31%|███       | 270/882 [02:28<05:13,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  31%|███       | 271/882 [02:29<05:13,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  31%|███       | 272/882 [02:29<05:12,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  31%|███       | 273/882 [02:30<05:33,  1.83it/s]
# [STDERR] Epoch 1/150 [Train]:  31%|███       | 274/882 [02:30<05:24,  1.87it/s]
# [STDERR] Epoch 1/150 [Train]:  31%|███       | 275/882 [02:31<05:20,  1.89it/s]
# [STDERR] Epoch 1/150 [Train]:  31%|███▏      | 276/882 [02:31<05:17,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  31%|███▏      | 277/882 [02:32<05:17,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  32%|███▏      | 278/882 [02:32<05:16,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  32%|███▏      | 279/882 [02:33<05:15,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  32%|███▏      | 280/882 [02:33<05:11,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  32%|███▏      | 281/882 [02:34<05:10,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  32%|███▏      | 282/882 [02:34<05:09,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  32%|███▏      | 283/882 [02:35<05:07,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  32%|███▏      | 284/882 [02:35<05:07,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  32%|███▏      | 285/882 [02:36<05:07,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  32%|███▏      | 286/882 [02:36<05:05,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  33%|███▎      | 287/882 [02:37<05:06,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  33%|███▎      | 288/882 [02:37<05:06,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  33%|███▎      | 289/882 [02:38<05:09,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  33%|███▎      | 290/882 [02:39<05:23,  1.83it/s]
# [STDERR] Epoch 1/150 [Train]:  33%|███▎      | 291/882 [02:39<05:17,  1.86it/s]
# [STDERR] Epoch 1/150 [Train]:  33%|███▎      | 292/882 [02:40<05:15,  1.87it/s]
# [STDERR] Epoch 1/150 [Train]:  33%|███▎      | 293/882 [02:40<05:11,  1.89it/s]
# [STDERR] Epoch 1/150 [Train]:  33%|███▎      | 294/882 [02:41<05:11,  1.89it/s]
# [STDERR] Epoch 1/150 [Train]:  33%|███▎      | 295/882 [02:41<05:09,  1.90it/s]
# [STDERR] Epoch 1/150 [Train]:  34%|███▎      | 296/882 [02:42<05:13,  1.87it/s]
# [STDERR] Epoch 1/150 [Train]:  34%|███▎      | 297/882 [02:42<05:09,  1.89it/s]
# [STDERR] Epoch 1/150 [Train]:  34%|███▍      | 298/882 [02:43<05:06,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  34%|███▍      | 299/882 [02:43<05:04,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  34%|███▍      | 300/882 [02:44<05:04,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  34%|███▍      | 301/882 [02:44<05:00,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  34%|███▍      | 302/882 [02:45<04:59,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  34%|███▍      | 303/882 [02:45<04:56,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  34%|███▍      | 304/882 [02:46<04:57,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  35%|███▍      | 305/882 [02:46<04:55,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  35%|███▍      | 306/882 [02:47<04:54,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  35%|███▍      | 307/882 [02:47<04:53,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  35%|███▍      | 308/882 [02:48<04:53,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  35%|███▌      | 309/882 [02:48<04:52,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  35%|███▌      | 310/882 [02:49<04:52,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  35%|███▌      | 311/882 [02:49<04:49,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  35%|███▌      | 312/882 [02:50<04:51,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  35%|███▌      | 313/882 [02:50<04:50,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  36%|███▌      | 314/882 [02:51<04:49,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  36%|███▌      | 315/882 [02:51<04:51,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  36%|███▌      | 316/882 [02:52<05:34,  1.69it/s]
# [STDERR] Epoch 1/150 [Train]:  36%|███▌      | 317/882 [02:53<07:07,  1.32it/s]
# [STDERR] Epoch 1/150 [Train]:  36%|███▌      | 318/882 [02:54<07:12,  1.30it/s]
# [STDERR] Epoch 1/150 [Train]:  36%|███▌      | 319/882 [02:55<06:53,  1.36it/s]
# [STDERR] Epoch 1/150 [Train]:  36%|███▋      | 320/882 [02:56<06:59,  1.34it/s]
# [STDERR] Epoch 1/150 [Train]:  36%|███▋      | 321/882 [02:56<06:27,  1.45it/s]
# [STDERR] Epoch 1/150 [Train]:  37%|███▋      | 322/882 [02:57<06:01,  1.55it/s]
# [STDERR] Epoch 1/150 [Train]:  37%|███▋      | 323/882 [02:57<05:39,  1.65it/s]
# [STDERR] Epoch 1/150 [Train]:  37%|███▋      | 324/882 [02:58<05:35,  1.66it/s]
# [STDERR] Epoch 1/150 [Train]:  37%|███▋      | 325/882 [02:58<05:18,  1.75it/s]
# [STDERR] Epoch 1/150 [Train]:  37%|███▋      | 326/882 [02:59<05:14,  1.77it/s]
# [STDERR] Epoch 1/150 [Train]:  37%|███▋      | 327/882 [02:59<05:06,  1.81it/s]
# [STDERR] Epoch 1/150 [Train]:  37%|███▋      | 328/882 [03:00<05:01,  1.84it/s]
# [STDERR] Epoch 1/150 [Train]:  37%|███▋      | 329/882 [03:00<04:57,  1.86it/s]
# [STDERR] Epoch 1/150 [Train]:  37%|███▋      | 330/882 [03:01<04:53,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  38%|███▊      | 331/882 [03:01<04:48,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  38%|███▊      | 332/882 [03:02<04:46,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  38%|███▊      | 333/882 [03:02<04:46,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  38%|███▊      | 334/882 [03:03<04:46,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  38%|███▊      | 335/882 [03:03<04:43,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  38%|███▊      | 336/882 [03:04<04:40,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  38%|███▊      | 337/882 [03:04<04:39,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  38%|███▊      | 338/882 [03:05<04:39,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  38%|███▊      | 339/882 [03:06<04:36,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  39%|███▊      | 340/882 [03:06<04:38,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  39%|███▊      | 341/882 [03:07<04:37,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  39%|███▉      | 342/882 [03:07<04:37,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  39%|███▉      | 343/882 [03:08<04:36,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  39%|███▉      | 344/882 [03:08<04:34,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  39%|███▉      | 345/882 [03:09<04:34,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  39%|███▉      | 346/882 [03:09<04:33,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  39%|███▉      | 347/882 [03:10<04:33,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  39%|███▉      | 348/882 [03:10<04:35,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  40%|███▉      | 349/882 [03:11<04:35,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  40%|███▉      | 350/882 [03:11<04:33,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  40%|███▉      | 351/882 [03:12<04:33,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  40%|███▉      | 352/882 [03:12<04:32,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  40%|████      | 353/882 [03:13<04:30,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  40%|████      | 354/882 [03:13<04:27,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  40%|████      | 355/882 [03:14<04:26,  1.98it/s]
# [STDERR] Epoch 1/150 [Train]:  40%|████      | 356/882 [03:14<04:27,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  40%|████      | 357/882 [03:15<04:28,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  41%|████      | 358/882 [03:15<04:28,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  41%|████      | 359/882 [03:16<04:27,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  41%|████      | 360/882 [03:16<04:29,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  41%|████      | 361/882 [03:17<04:27,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  41%|████      | 362/882 [03:17<04:26,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  41%|████      | 363/882 [03:18<04:25,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  41%|████▏     | 364/882 [03:18<04:25,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  41%|████▏     | 365/882 [03:19<04:26,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  41%|████▏     | 366/882 [03:19<04:28,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  42%|████▏     | 367/882 [03:20<04:24,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  42%|████▏     | 368/882 [03:20<04:23,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  42%|████▏     | 369/882 [03:21<04:23,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  42%|████▏     | 370/882 [03:21<04:21,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  42%|████▏     | 371/882 [03:22<04:22,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  42%|████▏     | 372/882 [03:22<04:24,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  42%|████▏     | 373/882 [03:23<04:22,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  42%|████▏     | 374/882 [03:23<04:20,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  43%|████▎     | 375/882 [03:24<04:29,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  43%|████▎     | 376/882 [03:25<04:24,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  43%|████▎     | 377/882 [03:25<04:21,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  43%|████▎     | 378/882 [03:26<04:19,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  43%|████▎     | 379/882 [03:26<04:19,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  43%|████▎     | 380/882 [03:27<04:17,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  43%|████▎     | 381/882 [03:27<04:17,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  43%|████▎     | 382/882 [03:28<04:15,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  43%|████▎     | 383/882 [03:28<04:15,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  44%|████▎     | 384/882 [03:29<04:14,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  44%|████▎     | 385/882 [03:29<04:13,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  44%|████▍     | 386/882 [03:30<04:12,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  44%|████▍     | 387/882 [03:30<04:10,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  44%|████▍     | 388/882 [03:31<04:14,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  44%|████▍     | 389/882 [03:31<04:15,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  44%|████▍     | 390/882 [03:32<04:13,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  44%|████▍     | 391/882 [03:32<04:12,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  44%|████▍     | 392/882 [03:33<04:11,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  45%|████▍     | 393/882 [03:33<04:09,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  45%|████▍     | 394/882 [03:34<04:07,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  45%|████▍     | 395/882 [03:34<04:09,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  45%|████▍     | 396/882 [03:35<04:09,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  45%|████▌     | 397/882 [03:35<04:09,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  45%|████▌     | 398/882 [03:36<04:08,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  45%|████▌     | 399/882 [03:36<04:10,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  45%|████▌     | 400/882 [03:37<04:08,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  45%|████▌     | 401/882 [03:37<04:08,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  46%|████▌     | 402/882 [03:38<04:05,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  46%|████▌     | 403/882 [03:38<04:05,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  46%|████▌     | 404/882 [03:39<04:09,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  46%|████▌     | 405/882 [03:40<04:19,  1.84it/s]
# [STDERR] Epoch 1/150 [Train]:  46%|████▌     | 406/882 [03:40<04:16,  1.86it/s]
# [STDERR] Epoch 1/150 [Train]:  46%|████▌     | 407/882 [03:41<04:13,  1.87it/s]
# [STDERR] Epoch 1/150 [Train]:  46%|████▋     | 408/882 [03:41<04:07,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  46%|████▋     | 409/882 [03:42<04:06,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  46%|████▋     | 410/882 [03:42<04:04,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  47%|████▋     | 411/882 [03:43<04:01,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  47%|████▋     | 412/882 [03:43<04:00,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  47%|████▋     | 413/882 [03:44<03:58,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  47%|████▋     | 414/882 [03:44<04:01,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  47%|████▋     | 415/882 [03:45<04:01,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  47%|████▋     | 416/882 [03:45<04:01,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  47%|████▋     | 417/882 [03:46<04:06,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  47%|████▋     | 418/882 [03:46<04:07,  1.87it/s]
# [STDERR] Epoch 1/150 [Train]:  48%|████▊     | 419/882 [03:47<04:06,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  48%|████▊     | 420/882 [03:47<04:02,  1.90it/s]
# [STDERR] Epoch 1/150 [Train]:  48%|████▊     | 421/882 [03:48<03:59,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  48%|████▊     | 422/882 [03:48<03:56,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  48%|████▊     | 423/882 [03:49<03:57,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  48%|████▊     | 424/882 [03:49<03:58,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  48%|████▊     | 425/882 [03:50<04:22,  1.74it/s]
# [STDERR] Epoch 1/150 [Train]:  48%|████▊     | 426/882 [03:51<04:32,  1.67it/s]
# [STDERR] Epoch 1/150 [Train]:  48%|████▊     | 427/882 [03:51<04:20,  1.75it/s]
# [STDERR] Epoch 1/150 [Train]:  49%|████▊     | 428/882 [03:52<04:12,  1.80it/s]
# [STDERR] Epoch 1/150 [Train]:  49%|████▊     | 429/882 [03:52<04:03,  1.86it/s]
# [STDERR] Epoch 1/150 [Train]:  49%|████▉     | 430/882 [03:53<03:57,  1.90it/s]
# [STDERR] Epoch 1/150 [Train]:  49%|████▉     | 431/882 [03:53<03:56,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  49%|████▉     | 432/882 [03:54<03:53,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  49%|████▉     | 433/882 [03:54<03:49,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  49%|████▉     | 434/882 [03:55<03:48,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  49%|████▉     | 435/882 [03:55<03:46,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  49%|████▉     | 436/882 [03:56<03:56,  1.89it/s]
# [STDERR] Epoch 1/150 [Train]:  50%|████▉     | 437/882 [03:56<03:50,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  50%|████▉     | 438/882 [03:57<03:52,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  50%|████▉     | 439/882 [03:57<03:50,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  50%|████▉     | 440/882 [03:58<03:57,  1.86it/s]
# [STDERR] Epoch 1/150 [Train]:  50%|█████     | 441/882 [03:58<03:51,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  50%|█████     | 442/882 [03:59<03:50,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  50%|█████     | 443/882 [03:59<03:46,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  50%|█████     | 444/882 [04:00<03:45,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  50%|█████     | 445/882 [04:00<03:42,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  51%|█████     | 446/882 [04:01<03:42,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  51%|█████     | 447/882 [04:02<03:40,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  51%|█████     | 448/882 [04:02<03:39,  1.98it/s]
# [STDERR] Epoch 1/150 [Train]:  51%|█████     | 449/882 [04:03<03:41,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  51%|█████     | 450/882 [04:03<03:40,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  51%|█████     | 451/882 [04:04<03:41,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  51%|█████     | 452/882 [04:04<03:39,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  51%|█████▏    | 453/882 [04:05<03:40,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  51%|█████▏    | 454/882 [04:05<03:40,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  52%|█████▏    | 455/882 [04:06<03:42,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  52%|█████▏    | 456/882 [04:06<03:48,  1.86it/s]
# [STDERR] Epoch 1/150 [Train]:  52%|█████▏    | 457/882 [04:07<03:45,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  52%|█████▏    | 458/882 [04:07<03:46,  1.87it/s]
# [STDERR] Epoch 1/150 [Train]:  52%|█████▏    | 459/882 [04:08<03:43,  1.89it/s]
# [STDERR] Epoch 1/150 [Train]:  52%|█████▏    | 460/882 [04:08<03:44,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  52%|█████▏    | 461/882 [04:09<03:39,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  52%|█████▏    | 462/882 [04:09<03:36,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  52%|█████▏    | 463/882 [04:10<03:34,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  53%|█████▎    | 464/882 [04:10<03:32,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  53%|█████▎    | 465/882 [04:11<03:31,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  53%|█████▎    | 466/882 [04:11<03:30,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  53%|█████▎    | 467/882 [04:12<03:33,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  53%|█████▎    | 468/882 [04:12<03:32,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  53%|█████▎    | 469/882 [04:13<03:49,  1.80it/s]
# [STDERR] Epoch 1/150 [Train]:  53%|█████▎    | 470/882 [04:14<03:43,  1.84it/s]
# [STDERR] Epoch 1/150 [Train]:  53%|█████▎    | 471/882 [04:14<03:39,  1.87it/s]
# [STDERR] Epoch 1/150 [Train]:  54%|█████▎    | 472/882 [04:15<03:37,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  54%|█████▎    | 473/882 [04:15<03:40,  1.85it/s]
# [STDERR] Epoch 1/150 [Train]:  54%|█████▎    | 474/882 [04:16<03:38,  1.87it/s]
# [STDERR] Epoch 1/150 [Train]:  54%|█████▍    | 475/882 [04:16<03:36,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  54%|█████▍    | 476/882 [04:17<03:34,  1.90it/s]
# [STDERR] Epoch 1/150 [Train]:  54%|█████▍    | 477/882 [04:17<03:33,  1.89it/s]
# [STDERR] Epoch 1/150 [Train]:  54%|█████▍    | 478/882 [04:18<03:31,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  54%|█████▍    | 479/882 [04:18<03:27,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  54%|█████▍    | 480/882 [04:19<03:26,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  55%|█████▍    | 481/882 [04:19<03:26,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  55%|█████▍    | 482/882 [04:20<03:25,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  55%|█████▍    | 483/882 [04:20<03:26,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  55%|█████▍    | 484/882 [04:21<03:24,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  55%|█████▍    | 485/882 [04:21<03:23,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  55%|█████▌    | 486/882 [04:22<03:25,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  55%|█████▌    | 487/882 [04:22<03:27,  1.90it/s]
# [STDERR] Epoch 1/150 [Train]:  55%|█████▌    | 488/882 [04:23<03:26,  1.90it/s]
# [STDERR] Epoch 1/150 [Train]:  55%|█████▌    | 489/882 [04:23<03:29,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  56%|█████▌    | 490/882 [04:24<03:28,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  56%|█████▌    | 491/882 [04:25<03:24,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  56%|█████▌    | 492/882 [04:25<03:22,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  56%|█████▌    | 493/882 [04:26<03:20,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  56%|█████▌    | 494/882 [04:26<03:21,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  56%|█████▌    | 495/882 [04:27<03:23,  1.90it/s]
# [STDERR] Epoch 1/150 [Train]:  56%|█████▌    | 496/882 [04:27<03:21,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  56%|█████▋    | 497/882 [04:28<03:20,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  56%|█████▋    | 498/882 [04:28<03:20,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  57%|█████▋    | 499/882 [04:29<03:22,  1.89it/s]
# [STDERR] Epoch 1/150 [Train]:  57%|█████▋    | 500/882 [04:29<03:20,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  57%|█████▋    | 501/882 [04:30<03:17,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  57%|█████▋    | 502/882 [04:30<03:15,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  57%|█████▋    | 503/882 [04:31<03:14,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  57%|█████▋    | 504/882 [04:31<03:13,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  57%|█████▋    | 505/882 [04:32<03:15,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  57%|█████▋    | 506/882 [04:32<03:14,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  57%|█████▋    | 507/882 [04:33<03:18,  1.89it/s]
# [STDERR] Epoch 1/150 [Train]:  58%|█████▊    | 508/882 [04:33<03:19,  1.87it/s]
# [STDERR] Epoch 1/150 [Train]:  58%|█████▊    | 509/882 [04:34<03:22,  1.84it/s]
# [STDERR] Epoch 1/150 [Train]:  58%|█████▊    | 510/882 [04:34<03:21,  1.85it/s]
# [STDERR] Epoch 1/150 [Train]:  58%|█████▊    | 511/882 [04:35<03:20,  1.85it/s]
# [STDERR] Epoch 1/150 [Train]:  58%|█████▊    | 512/882 [04:36<03:19,  1.85it/s]
# [STDERR] Epoch 1/150 [Train]:  58%|█████▊    | 513/882 [04:36<03:19,  1.85it/s]
# [STDERR] Epoch 1/150 [Train]:  58%|█████▊    | 514/882 [04:37<03:24,  1.80it/s]
# [STDERR] Epoch 1/150 [Train]:  58%|█████▊    | 515/882 [04:37<03:32,  1.72it/s]
# [STDERR] Epoch 1/150 [Train]:  59%|█████▊    | 516/882 [04:39<05:13,  1.17it/s]
# [STDERR] Epoch 1/150 [Train]:  59%|█████▊    | 517/882 [04:40<05:35,  1.09it/s]
# [STDERR] Epoch 1/150 [Train]:  59%|█████▊    | 518/882 [04:42<07:51,  1.30s/it]
# [STDERR] Epoch 1/150 [Train]:  59%|█████▉    | 519/882 [04:43<06:38,  1.10s/it]
# [STDERR] Epoch 1/150 [Train]:  59%|█████▉    | 520/882 [04:43<05:42,  1.06it/s]
# [STDERR] Epoch 1/150 [Train]:  59%|█████▉    | 521/882 [04:44<04:58,  1.21it/s]
# [STDERR] Epoch 1/150 [Train]:  59%|█████▉    | 522/882 [04:44<04:29,  1.34it/s]
# [STDERR] Epoch 1/150 [Train]:  59%|█████▉    | 523/882 [04:45<04:07,  1.45it/s]
# [STDERR] Epoch 1/150 [Train]:  59%|█████▉    | 524/882 [04:45<03:45,  1.59it/s]
# [STDERR] Epoch 1/150 [Train]:  60%|█████▉    | 525/882 [04:46<03:40,  1.62it/s]
# [STDERR] Epoch 1/150 [Train]:  60%|█████▉    | 526/882 [04:47<03:42,  1.60it/s]
# [STDERR] Epoch 1/150 [Train]:  60%|█████▉    | 527/882 [04:47<03:39,  1.62it/s]
# [STDERR] Epoch 1/150 [Train]:  60%|█████▉    | 528/882 [04:48<03:32,  1.67it/s]
# [STDERR] Epoch 1/150 [Train]:  60%|█████▉    | 529/882 [04:48<03:25,  1.72it/s]
# [STDERR] Epoch 1/150 [Train]:  60%|██████    | 530/882 [04:49<03:30,  1.67it/s]
# [STDERR] Epoch 1/150 [Train]:  60%|██████    | 531/882 [04:50<03:26,  1.70it/s]
# [STDERR] Epoch 1/150 [Train]:  60%|██████    | 532/882 [04:50<03:36,  1.62it/s]
# [STDERR] Epoch 1/150 [Train]:  60%|██████    | 533/882 [04:51<03:55,  1.49it/s]
# [STDERR] Epoch 1/150 [Train]:  61%|██████    | 534/882 [04:52<03:38,  1.60it/s]
# [STDERR] Epoch 1/150 [Train]:  61%|██████    | 535/882 [04:52<03:30,  1.65it/s]
# [STDERR] Epoch 1/150 [Train]:  61%|██████    | 536/882 [04:53<03:19,  1.74it/s]
# [STDERR] Epoch 1/150 [Train]:  61%|██████    | 537/882 [04:53<03:11,  1.81it/s]
# [STDERR] Epoch 1/150 [Train]:  61%|██████    | 538/882 [04:54<03:05,  1.86it/s]
# [STDERR] Epoch 1/150 [Train]:  61%|██████    | 539/882 [04:54<03:02,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  61%|██████    | 540/882 [04:55<03:00,  1.90it/s]
# [STDERR] Epoch 1/150 [Train]:  61%|██████▏   | 541/882 [04:55<02:56,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  61%|██████▏   | 542/882 [04:56<02:55,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  62%|██████▏   | 543/882 [04:56<02:55,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  62%|██████▏   | 544/882 [04:57<02:57,  1.90it/s]
# [STDERR] Epoch 1/150 [Train]:  62%|██████▏   | 545/882 [04:57<02:55,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  62%|██████▏   | 546/882 [04:58<02:54,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  62%|██████▏   | 547/882 [04:58<02:52,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  62%|██████▏   | 548/882 [04:59<02:54,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  62%|██████▏   | 549/882 [04:59<02:53,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  62%|██████▏   | 550/882 [05:00<02:52,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  62%|██████▏   | 551/882 [05:00<02:51,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  63%|██████▎   | 552/882 [05:01<02:51,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  63%|██████▎   | 553/882 [05:01<02:50,  1.93it/s]
# [STDERR] Epoch 1/150 [Train]:  63%|██████▎   | 554/882 [05:02<02:48,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  63%|██████▎   | 555/882 [05:02<02:47,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  63%|██████▎   | 556/882 [05:03<02:46,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  63%|██████▎   | 557/882 [05:03<02:45,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  63%|██████▎   | 558/882 [05:04<02:43,  1.98it/s]
# [STDERR] Epoch 1/150 [Train]:  63%|██████▎   | 559/882 [05:05<02:46,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  63%|██████▎   | 560/882 [05:05<02:45,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  64%|██████▎   | 561/882 [05:06<02:44,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  64%|██████▎   | 562/882 [05:06<02:42,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  64%|██████▍   | 563/882 [05:07<02:42,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  64%|██████▍   | 564/882 [05:07<02:40,  1.98it/s]
# [STDERR] Epoch 1/150 [Train]:  64%|██████▍   | 565/882 [05:08<02:40,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  64%|██████▍   | 566/882 [05:08<02:51,  1.85it/s]
# [STDERR] Epoch 1/150 [Train]:  64%|██████▍   | 567/882 [05:09<02:47,  1.88it/s]
# [STDERR] Epoch 1/150 [Train]:  64%|██████▍   | 568/882 [05:09<02:44,  1.91it/s]
# [STDERR] Epoch 1/150 [Train]:  65%|██████▍   | 569/882 [05:10<02:42,  1.92it/s]
# [STDERR] Epoch 1/150 [Train]:  65%|██████▍   | 570/882 [05:10<02:40,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  65%|██████▍   | 571/882 [05:11<02:39,  1.94it/s]
# [STDERR] Epoch 1/150 [Train]:  65%|██████▍   | 572/882 [05:11<02:38,  1.95it/s]
# [STDERR] Epoch 1/150 [Train]:  65%|██████▍   | 573/882 [05:12<02:37,  1.96it/s]
# [STDERR] Epoch 1/150 [Train]:  65%|██████▌   | 574/882 [05:12<02:36,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  65%|██████▌   | 575/882 [05:13<02:35,  1.98it/s]
# [STDERR] Epoch 1/150 [Train]:  65%|██████▌   | 576/882 [05:13<02:34,  1.98it/s]
# [STDERR] Epoch 1/150 [Train]:  65%|██████▌   | 577/882 [05:14<02:34,  1.98it/s]
# [STDERR] Epoch 1/150 [Train]:  66%|██████▌   | 578/882 [05:14<02:34,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  66%|██████▌   | 579/882 [05:15<02:34,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  66%|██████▌   | 580/882 [05:15<02:32,  1.97it/s]
# [STDERR] Epoch 1/150 [Train]:  66%|██████▌   | 581/882 [05:16<02:32,  1.98it/s]
# ...
# [STDERR] Epoch 23/150 [Train]:  42%|████▏     | 374/882 [01:48<01:48,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  43%|████▎     | 375/882 [01:48<01:47,  4.70it/s]
# [STDERR] Epoch 23/150 [Train]:  43%|████▎     | 376/882 [01:48<01:47,  4.72it/s]
# [STDERR] Epoch 23/150 [Train]:  43%|████▎     | 377/882 [01:49<01:46,  4.73it/s]
# [STDERR] Epoch 23/150 [Train]:  43%|████▎     | 378/882 [01:49<01:46,  4.72it/s]
# [STDERR] Epoch 23/150 [Train]:  43%|████▎     | 379/882 [01:49<01:46,  4.73it/s]
# [STDERR] Epoch 23/150 [Train]:  43%|████▎     | 380/882 [01:49<01:45,  4.75it/s]
# [STDERR] Epoch 23/150 [Train]:  43%|████▎     | 381/882 [01:49<01:45,  4.75it/s]
# [STDERR] Epoch 23/150 [Train]:  43%|████▎     | 382/882 [01:50<01:45,  4.74it/s]
# [STDERR] Epoch 23/150 [Train]:  43%|████▎     | 383/882 [01:50<01:45,  4.73it/s]
# [STDERR] Epoch 23/150 [Train]:  44%|████▎     | 384/882 [01:50<01:44,  4.75it/s]
# [STDERR] Epoch 23/150 [Train]:  44%|████▎     | 385/882 [01:50<01:44,  4.76it/s]
# [STDERR] Epoch 23/150 [Train]:  44%|████▍     | 386/882 [01:50<01:45,  4.70it/s]
# [STDERR] Epoch 23/150 [Train]:  44%|████▍     | 387/882 [01:51<01:45,  4.69it/s]
# [STDERR] Epoch 23/150 [Train]:  44%|████▍     | 388/882 [01:51<01:45,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  44%|████▍     | 389/882 [01:51<01:44,  4.70it/s]
# [STDERR] Epoch 23/150 [Train]:  44%|████▍     | 390/882 [01:51<01:45,  4.67it/s]
# [STDERR] Epoch 23/150 [Train]:  44%|████▍     | 391/882 [01:52<01:44,  4.69it/s]
# [STDERR] Epoch 23/150 [Train]:  44%|████▍     | 392/882 [01:52<01:43,  4.73it/s]
# [STDERR] Epoch 23/150 [Train]:  45%|████▍     | 393/882 [01:52<01:43,  4.71it/s]
# [STDERR] Epoch 23/150 [Train]:  45%|████▍     | 394/882 [01:52<01:43,  4.70it/s]
# [STDERR] Epoch 23/150 [Train]:  45%|████▍     | 395/882 [01:52<01:44,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  45%|████▍     | 396/882 [01:53<01:44,  4.66it/s]
# [STDERR] Epoch 23/150 [Train]:  45%|████▌     | 397/882 [01:53<01:43,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  45%|████▌     | 398/882 [01:53<01:43,  4.67it/s]
# [STDERR] Epoch 23/150 [Train]:  45%|████▌     | 399/882 [01:53<01:43,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  45%|████▌     | 400/882 [01:53<01:43,  4.66it/s]
# [STDERR] Epoch 23/150 [Train]:  45%|████▌     | 401/882 [01:54<01:43,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  46%|████▌     | 402/882 [01:54<01:43,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  46%|████▌     | 403/882 [01:54<01:42,  4.67it/s]
# [STDERR] Epoch 23/150 [Train]:  46%|████▌     | 404/882 [01:54<01:42,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  46%|████▌     | 405/882 [01:55<01:42,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  46%|████▌     | 406/882 [01:55<01:42,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  46%|████▌     | 407/882 [01:55<01:42,  4.63it/s]
# [STDERR] Epoch 23/150 [Train]:  46%|████▋     | 408/882 [01:55<01:42,  4.62it/s]
# [STDERR] Epoch 23/150 [Train]:  46%|████▋     | 409/882 [01:55<01:46,  4.46it/s]
# [STDERR] Epoch 23/150 [Train]:  46%|████▋     | 410/882 [01:56<01:48,  4.34it/s]
# [STDERR] Epoch 23/150 [Train]:  47%|████▋     | 411/882 [01:56<01:51,  4.22it/s]
# [STDERR] Epoch 23/150 [Train]:  47%|████▋     | 412/882 [01:56<01:50,  4.26it/s]
# [STDERR] Epoch 23/150 [Train]:  47%|████▋     | 413/882 [01:56<01:52,  4.18it/s]
# [STDERR] Epoch 23/150 [Train]:  47%|████▋     | 414/882 [01:57<01:53,  4.13it/s]
# [STDERR] Epoch 23/150 [Train]:  47%|████▋     | 415/882 [01:57<01:56,  4.00it/s]
# [STDERR] Epoch 23/150 [Train]:  47%|████▋     | 416/882 [01:57<01:54,  4.08it/s]
# [STDERR] Epoch 23/150 [Train]:  47%|████▋     | 417/882 [01:57<01:50,  4.21it/s]
# [STDERR] Epoch 23/150 [Train]:  47%|████▋     | 418/882 [01:58<01:45,  4.38it/s]
# [STDERR] Epoch 23/150 [Train]:  48%|████▊     | 419/882 [01:58<01:44,  4.44it/s]
# [STDERR] Epoch 23/150 [Train]:  48%|████▊     | 420/882 [01:58<01:42,  4.50it/s]
# [STDERR] Epoch 23/150 [Train]:  48%|████▊     | 421/882 [01:58<01:41,  4.53it/s]
# [STDERR] Epoch 23/150 [Train]:  48%|████▊     | 422/882 [01:58<01:42,  4.48it/s]
# [STDERR] Epoch 23/150 [Train]:  48%|████▊     | 423/882 [01:59<01:41,  4.54it/s]
# [STDERR] Epoch 23/150 [Train]:  48%|████▊     | 424/882 [01:59<01:39,  4.59it/s]
# [STDERR] Epoch 23/150 [Train]:  48%|████▊     | 425/882 [01:59<01:38,  4.62it/s]
# [STDERR] Epoch 23/150 [Train]:  48%|████▊     | 426/882 [01:59<01:38,  4.63it/s]
# [STDERR] Epoch 23/150 [Train]:  48%|████▊     | 427/882 [02:00<01:37,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  49%|████▊     | 428/882 [02:00<01:37,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  49%|████▊     | 429/882 [02:00<01:36,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  49%|████▉     | 430/882 [02:00<01:36,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  49%|████▉     | 431/882 [02:00<01:36,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  49%|████▉     | 432/882 [02:01<01:37,  4.64it/s]
# [STDERR] Epoch 23/150 [Train]:  49%|████▉     | 433/882 [02:01<01:37,  4.61it/s]
# [STDERR] Epoch 23/150 [Train]:  49%|████▉     | 434/882 [02:01<01:36,  4.62it/s]
# [STDERR] Epoch 23/150 [Train]:  49%|████▉     | 435/882 [02:01<01:36,  4.62it/s]
# [STDERR] Epoch 23/150 [Train]:  49%|████▉     | 436/882 [02:01<01:36,  4.63it/s]
# [STDERR] Epoch 23/150 [Train]:  50%|████▉     | 437/882 [02:02<01:35,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  50%|████▉     | 438/882 [02:02<01:34,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  50%|████▉     | 439/882 [02:02<01:34,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  50%|████▉     | 440/882 [02:02<01:35,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  50%|█████     | 441/882 [02:03<01:33,  4.69it/s]
# [STDERR] Epoch 23/150 [Train]:  50%|█████     | 442/882 [02:03<01:37,  4.52it/s]
# [STDERR] Epoch 23/150 [Train]:  50%|█████     | 443/882 [02:03<01:35,  4.58it/s]
# [STDERR] Epoch 23/150 [Train]:  50%|█████     | 444/882 [02:03<01:34,  4.63it/s]
# [STDERR] Epoch 23/150 [Train]:  50%|█████     | 445/882 [02:03<01:33,  4.66it/s]
# [STDERR] Epoch 23/150 [Train]:  51%|█████     | 446/882 [02:04<01:33,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  51%|█████     | 447/882 [02:04<01:33,  4.67it/s]
# [STDERR] Epoch 23/150 [Train]:  51%|█████     | 448/882 [02:04<01:33,  4.66it/s]
# [STDERR] Epoch 23/150 [Train]:  51%|█████     | 449/882 [02:04<01:34,  4.59it/s]
# [STDERR] Epoch 23/150 [Train]:  51%|█████     | 450/882 [02:04<01:33,  4.61it/s]
# [STDERR] Epoch 23/150 [Train]:  51%|█████     | 451/882 [02:05<01:32,  4.64it/s]
# [STDERR] Epoch 23/150 [Train]:  51%|█████     | 452/882 [02:05<01:32,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  51%|█████▏    | 453/882 [02:05<01:31,  4.67it/s]
# [STDERR] Epoch 23/150 [Train]:  51%|█████▏    | 454/882 [02:05<01:31,  4.67it/s]
# [STDERR] Epoch 23/150 [Train]:  52%|█████▏    | 455/882 [02:06<01:30,  4.72it/s]
# [STDERR] Epoch 23/150 [Train]:  52%|█████▏    | 456/882 [02:06<01:34,  4.52it/s]
# [STDERR] Epoch 23/150 [Train]:  52%|█████▏    | 457/882 [02:06<01:32,  4.60it/s]
# [STDERR] Epoch 23/150 [Train]:  52%|█████▏    | 458/882 [02:06<01:30,  4.66it/s]
# [STDERR] Epoch 23/150 [Train]:  52%|█████▏    | 459/882 [02:06<01:31,  4.64it/s]
# [STDERR] Epoch 23/150 [Train]:  52%|█████▏    | 460/882 [02:07<01:30,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  52%|█████▏    | 461/882 [02:07<01:29,  4.69it/s]
# [STDERR] Epoch 23/150 [Train]:  52%|█████▏    | 462/882 [02:07<01:30,  4.66it/s]
# [STDERR] Epoch 23/150 [Train]:  52%|█████▏    | 463/882 [02:07<01:29,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  53%|█████▎    | 464/882 [02:07<01:29,  4.68it/s]
# [STDERR] Epoch 23/150 [Train]:  53%|█████▎    | 465/882 [02:08<01:29,  4.66it/s]
# [STDERR] Epoch 23/150 [Train]:  53%|█████▎    | 466/882 [02:08<01:28,  4.67it/s]
# [STDERR] Epoch 23/150 [Train]:  53%|█████▎    | 467/882 [02:08<01:28,  4.69it/s]
# [STDERR] Epoch 23/150 [Train]:  53%|█████▎    | 468/882 [02:08<01:29,  4.64it/s]
# [STDERR] Epoch 23/150 [Train]:  53%|█████▎    | 469/882 [02:09<01:33,  4.40it/s]
# [STDERR] Epoch 23/150 [Train]:  53%|█████▎    | 470/882 [02:09<01:36,  4.27it/s]
# [STDERR] Epoch 23/150 [Train]:  53%|█████▎    | 471/882 [02:09<01:47,  3.83it/s]
# [STDERR] Epoch 23/150 [Train]:  54%|█████▎    | 472/882 [02:09<01:46,  3.83it/s]
# [STDERR] Epoch 23/150 [Train]:  54%|█████▎    | 473/882 [02:10<01:40,  4.05it/s]
# [STDERR] Epoch 23/150 [Train]:  54%|█████▎    | 474/882 [02:10<01:41,  4.04it/s]
# [STDERR] Epoch 23/150 [Train]:  54%|█████▍    | 475/882 [02:10<01:38,  4.15it/s]
# [STDERR] Epoch 23/150 [Train]:  54%|█████▍    | 476/882 [02:10<01:42,  3.96it/s]
# [STDERR] Epoch 23/150 [Train]:  54%|█████▍    | 477/882 [02:11<01:45,  3.84it/s]
# [STDERR] Epoch 23/150 [Train]:  54%|█████▍    | 478/882 [02:11<01:43,  3.91it/s]
# [STDERR] Epoch 23/150 [Train]:  54%|█████▍    | 479/882 [02:11<01:38,  4.11it/s]
# [STDERR] Epoch 23/150 [Train]:  54%|█████▍    | 480/882 [02:11<01:37,  4.12it/s]
# [STDERR] Epoch 23/150 [Train]:  55%|█████▍    | 481/882 [02:12<01:35,  4.18it/s]
# [STDERR] Epoch 23/150 [Train]:  55%|█████▍    | 482/882 [02:12<02:07,  3.13it/s]
# [STDERR] Epoch 23/150 [Train]:  55%|█████▍    | 483/882 [02:13<02:19,  2.87it/s]
# [STDERR] Epoch 23/150 [Train]:  55%|█████▍    | 484/882 [02:13<02:49,  2.35it/s]
# [STDERR] Epoch 23/150 [Train]:  55%|█████▍    | 485/882 [02:13<02:33,  2.58it/s]
# [STDERR] Epoch 23/150 [Train]:  55%|█████▌    | 486/882 [02:14<02:34,  2.56it/s]
# [STDERR] Epoch 23/150 [Train]:  55%|█████▌    | 487/882 [02:14<03:00,  2.19it/s]
# [STDERR] Epoch 23/150 [Train]:  55%|█████▌    | 488/882 [02:15<03:12,  2.05it/s]
# [STDERR] Epoch 23/150 [Train]:  55%|█████▌    | 489/882 [02:15<02:56,  2.22it/s]
# [STDERR] Epoch 23/150 [Train]:  56%|█████▌    | 490/882 [02:16<03:14,  2.02it/s]
# [STDERR] Epoch 23/150 [Train]:  56%|█████▌    | 491/882 [02:17<03:33,  1.83it/s]
# [STDERR] Epoch 23/150 [Train]:  56%|█████▌    | 492/882 [02:17<03:01,  2.15it/s]
# [STDERR] Epoch 23/150 [Train]:  56%|█████▌    | 493/882 [02:17<02:35,  2.50it/s]
# [STDERR] Epoch 23/150 [Train]:  56%|█████▌    | 494/882 [02:17<02:20,  2.77it/s]
# [STDERR] Epoch 23/150 [Train]:  56%|█████▌    | 495/882 [02:18<02:03,  3.12it/s]
# [STDERR] Epoch 23/150 [Train]:  56%|█████▌    | 496/882 [02:18<01:50,  3.49it/s]
# [STDERR] Epoch 23/150 [Train]:  56%|█████▋    | 497/882 [02:18<01:41,  3.80it/s]
# [STDERR] Epoch 23/150 [Train]:  56%|█████▋    | 498/882 [02:18<01:50,  3.49it/s]
# [STDERR] Epoch 23/150 [Train]:  57%|█████▋    | 499/882 [02:19<02:20,  2.72it/s]
# [STDERR] Epoch 23/150 [Train]:  57%|█████▋    | 500/882 [02:19<02:06,  3.02it/s]
# [STDERR] Epoch 23/150 [Train]:  57%|█████▋    | 501/882 [02:20<02:30,  2.53it/s]
# [STDERR] Epoch 23/150 [Train]:  57%|█████▋    | 502/882 [02:20<02:13,  2.85it/s]
# [STDERR] Epoch 23/150 [Train]:  57%|█████▋    | 503/882 [02:20<02:04,  3.03it/s]
# [STDERR] Epoch 23/150 [Train]:  57%|█████▋    | 504/882 [02:21<01:55,  3.28it/s]
# [STDERR] Epoch 23/150 [Train]:  57%|█████▋    | 505/882 [02:21<02:16,  2.75it/s]
# [STDERR] Epoch 23/150 [Train]:  57%|█████▋    | 506/882 [02:21<02:01,  3.09it/s]
# [STDERR] Epoch 23/150 [Train]:  57%|█████▋    | 507/882 [02:22<01:50,  3.38it/s]
# [STDERR] Epoch 23/150 [Train]:  58%|█████▊    | 508/882 [02:22<01:46,  3.52it/s]
# [STDERR] Epoch 23/150 [Train]:  58%|█████▊    | 509/882 [02:22<01:45,  3.54it/s]
# [STDERR] Epoch 23/150 [Train]:  58%|█████▊    | 510/882 [02:22<01:39,  3.74it/s]
# [STDERR] Epoch 23/150 [Train]:  58%|█████▊    | 511/882 [02:22<01:34,  3.93it/s]
# [STDERR] Epoch 23/150 [Train]:  58%|█████▊    | 512/882 [02:23<01:31,  4.07it/s]
# [STDERR] Epoch 23/150 [Train]:  58%|█████▊    | 513/882 [02:23<01:41,  3.65it/s]
# [STDERR] Epoch 23/150 [Train]:  58%|█████▊    | 514/882 [02:23<01:50,  3.33it/s]
# [STDERR] Epoch 23/150 [Train]:  58%|█████▊    | 515/882 [02:24<01:41,  3.62it/s]
# [STDERR] Epoch 23/150 [Train]:  59%|█████▊    | 516/882 [02:24<01:33,  3.92it/s]
# [STDERR] Epoch 23/150 [Train]:  59%|█████▊    | 517/882 [02:24<01:27,  4.16it/s]
# [STDERR] Epoch 23/150 [Train]:  59%|█████▊    | 518/882 [02:24<01:24,  4.28it/s]
# [STDERR] Epoch 23/150 [Train]:  59%|█████▉    | 519/882 [02:24<01:22,  4.38it/s]
# [STDERR] Epoch 23/150 [Train]:  59%|█████▉    | 520/882 [02:25<01:21,  4.46it/s]
# [STDERR] Epoch 23/150 [Train]:  59%|█████▉    | 521/882 [02:25<01:19,  4.54it/s]
# [STDERR] Epoch 23/150 [Train]:  59%|█████▉    | 522/882 [02:25<01:18,  4.61it/s]
# [STDERR] Epoch 23/150 [Train]:  59%|█████▉    | 523/882 [02:25<01:17,  4.65it/s]
# [STDERR] Epoch 23/150 [Train]:  59%|█████▉    | 524/882 [02:26<01:17,  4.60it/s]
# [STDERR] Epoch 23/150 [Train]:  60%|█████▉    | 525/882 [02:26<01:18,  4.54it/s]
# [STDERR] Epoch 23/150 [Train]:  60%|█████▉    | 526/882 [02:26<01:17,  4.61it/s]
# [STDERR] Epoch 23/150 [Train]:  60%|█████▉    | 527/882 [02:26<01:17,  4.56it/s]
# [STDERR] Epoch 23/150 [Train]:  60%|█████▉    | 528/882 [02:26<01:18,  4.53it/s]
# [STDERR] Epoch 23/150 [Train]:  60%|█████▉    | 529/882 [02:27<01:18,  4.50it/s]
# [STDERR] Epoch 23/150 [Train]:  60%|██████    | 530/882 [02:27<01:16,  4.63it/s]
# [STDERR] Epoch 23/150 [Train]:  60%|██████    | 531/882 [02:27<01:26,  4.07it/s]
# [STDERR] Epoch 23/150 [Train]:  60%|██████    | 532/882 [02:27<01:25,  4.07it/s]
# [STDERR] Epoch 23/150 [Train]:  60%|██████    | 533/882 [02:28<01:45,  3.31it/s]
# [STDERR] Epoch 23/150 [Train]:  61%|██████    | 534/882 [02:28<01:37,  3.55it/s]
# [STDERR] Epoch 23/150 [Train]:  61%|██████    | 535/882 [02:28<01:30,  3.83it/s]
# [STDERR] Epoch 23/150 [Train]:  61%|██████    | 536/882 [02:29<01:25,  4.06it/s]
# [STDERR] Epoch 23/150 [Train]:  61%|██████    | 537/882 [02:29<01:21,  4.24it/s]
# [STDERR] Epoch 23/150 [Train]:  61%|██████    | 538/882 [02:29<01:19,  4.35it/s]
# [STDERR] Epoch 23/150 [Train]:  61%|██████    | 539/882 [02:29<01:15,  4.53it/s]
# [STDERR] Epoch 23/150 [Train]:  61%|██████    | 540/882 [02:29<01:16,  4.50it/s]
# [STDERR] Epoch 23/150 [Train]:  61%|██████▏   | 541/882 [02:30<01:14,  4.58it/s]
# [STDERR] Epoch 23/150 [Train]:  61%|██████▏   | 542/882 [02:30<01:14,  4.59it/s]
# [STDERR] Epoch 23/150 [Train]:  62%|██████▏   | 543/882 [02:30<01:13,  4.59it/s]
# [STDERR] Epoch 23/150 [Train]:  62%|██████▏   | 544/882 [02:30<01:12,  4.67it/s]
# [STDERR] Epoch 23/150 [Train]:  62%|██████▏   | 545/882 [02:30<01:12,  4.64it/s]
# [STDERR] Epoch 23/150 [Train]:  62%|██████▏   | 546/882 [02:31<01:12,  4.62it/s]
# [STDERR] Epoch 23/150 [Train]:  62%|██████▏   | 547/882 [02:31<01:13,  4.53it/s]
# [STDERR] Epoch 23/150 [Train]:  62%|██████▏   | 548/882 [02:31<01:13,  4.56it/s]
# [STDERR] Epoch 23/150 [Train]:  62%|██████▏   | 549/882 [02:31<01:12,  4.62it/s]
# [STDERR] Epoch 23/150 [Train]:  62%|██████▏   | 550/882 [02:32<01:12,  4.57it/s]
# [STDERR] Epoch 23/150 [Train]:  62%|██████▏   | 551/882 [02:32<01:11,  4.64it/s]
# [STDERR] Epoch 23/150 [Train]:  63%|██████▎   | 552/882 [02:32<01:10,  4.69it/s]
# [STDERR] Epoch 23/150 [Train]:  63%|██████▎   | 553/882 [02:32<01:09,  4.72it/s]
# [STDERR] Epoch 23/150 [Train]:  63%|██████▎   | 554/882 [02:32<01:10,  4.63it/s]
# [STDERR] Epoch 23/150 [Train]:  63%|██████▎   | 555/882 [02:33<01:09,  4.69it/s]
# [STDERR] Epoch 23/150 [Train]:  63%|██████▎   | 556/882 [02:33<01:10,  4.61it/s]
# [STDERR] Epoch 23/150 [Train]:  63%|██████▎   | 557/882 [02:33<01:09,  4.66it/s]
# [STDERR] Epoch 23/150 [Train]:  63%|██████▎   | 558/882 [02:33<01:12,  4.49it/s]
# [STDERR] Epoch 23/150 [Train]:  63%|██████▎   | 559/882 [02:33<01:10,  4.60it/s]
# [STDERR] Epoch 23/150 [Train]:  63%|██████▎   | 560/882 [02:34<01:11,  4.50it/s]
# [STDERR] Epoch 23/150 [Train]:  64%|██████▎   | 561/882 [02:34<01:11,  4.52it/s]
# [STDERR] Epoch 23/150 [Train]:  64%|██████▎   | 562/882 [02:34<01:10,  4.55it/s]
# [STDERR] Epoch 23/150 [Train]:  64%|██████▍   | 563/882 [02:34<01:13,  4.37it/s]
# [STDERR] Epoch 23/150 [Train]:  64%|██████▍   | 564/882 [02:35<01:12,  4.39it/s]
# [STDERR] Epoch 23/150 [Train]:  64%|██████▍   | 565/882 [02:35<01:12,  4.38it/s]
# [STDERR] Epoch 23/150 [Train]:  64%|██████▍   | 566/882 [02:35<01:09,  4.53it/s]
# [STDERR] Epoch 23/150 [Train]:  64%|██████▍   | 567/882 [02:35<01:10,  4.45it/s]
# [STDERR] Epoch 23/150 [Train]:  64%|██████▍   | 568/882 [02:36<01:09,  4.51it/s]
# [STDERR] Epoch 23/150 [Train]:  65%|██████▍   | 569/882 [02:36<01:09,  4.51it/s]
# [STDERR] Epoch 23/150 [Train]:  65%|██████▍   | 570/882 [02:36<01:08,  4.57it/s]

# %% [markdown]
# # functions

# %% [markdown]
# ## reload

# %%
def reload_modules():
    import importlib
    import utils.data_loading as data_loading
    import utils.visualization as visualization
    import utils.dataframes as dataframes
    import utils.utils_transforms as u_transforms
    import utils.training_utils as training_utils
    import utils.model_utils as model_utils
    import utils.file_IO as file_IO
    import utils.vit_rollout_mod as vit_rollout_mod
    import  utils.script_launching as script_launching
    
    importlib.reload(file_IO)
    importlib.reload(data_loading)
    importlib.reload(visualization)
    importlib.reload(dataframes)
    importlib.reload(u_transforms)
    importlib.reload(model_utils)
    importlib.reload(training_utils)
    importlib.reload(vit_rollout_mod)
    importlib.reload(script_launching)

    return data_loading, visualization, dataframes, u_transforms, training_utils, model_utils, file_IO, vit_rollout_mod, script_launching
data_loading, visualization, dataframes, u_transforms, training_utils, model_utils, file_IO, vit_rollout_mod, script_launching = reload_modules()
